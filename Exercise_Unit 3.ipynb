# %%
# !pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in c:\users\pauli\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\pauli\anaconda3\lib\site-packages (from wikipedia) (4.11.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\pauli\anaconda3\lib\site-packages (from wikipedia) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\pauli\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pauli\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pauli\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pauli\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pauli\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.3.1)

# %%
import wikipedia
from nltk import bigrams
from nltk.tokenize import word_tokenize
from collections import Counter
import string
import math

# 1. Use the Wikipedia python module and access any topic, as you will use that as your corpus, with a word limit of 1000 words. We chose Decision Problem.
# Fetch Wikipedia page
wikipedia_page = wikipedia.page("Decision problem")

# Extract first 1000 words
training_text = ' '.join(wikipedia_page.content.split()[:1000])  # Limit to 1000 words

# Display extracted text
print("Extracted Training Text (First 1000 Words):\n")
print(training_text)

# 2. Train a Bigram Model
# Tokenization - Converts text to lowercase, tokenizes words, and removes punctuation
tokennized_words = [word for word in word_tokenize(training_text.lower()) if word.isalnum()]
print("Tokens:", tokennized_words, "\n")

# Counts of Unigrams and Bigrams
unigram_frequency = Counter(tokennized_words) 
bigram_frequency = Counter(bigrams(tokennized_words)) 

# Show Unigram Counts
print("Unigram Counts:")
for unigram, count in unigram_frequency.items():
    print(f"{unigram}: {count}")

# Show Bigram Counts
print("\nBigram Counts:")
for bigram, count in bigram_frequency.items():
    print(f"{bigram}: {count}")

# Computes bigram probabilities
print("\nBigram Probabilities:")
def compute_bigram_probabilities(tokennized_words):
    bigram_probability = {bigram: count / unigram_frequency[bigram[0]] 
                    for bigram, count in bigram_frequency.items()}
    return bigram_probability

# Train the bigram model
bigram_probability = compute_bigram_probabilities(tokennized_words)

# Show Bigram Probabilities
for bigram, prob in bigram_probability.items():
    print(f"P({bigram[1]} | {bigram[0]}) = {prob:.4f}")

# Predict next word
def predict_next_word(bigram_probability, current_word):
    candidates = {k[1]: v for k, v in bigram_probability.items() if k[0] == current_word}
    return max(candidates, key=candidates.get) if candidates else None

# Predict Test word
predicted_word = predict_next_word(bigram_probability, "problem")
print(f"\nPredicted next word after 'problem': {predicted_word}")

# Generate text
def generate_bigram_text(bigram_model, start_word, length=10):
    current_word = start_word.lower()
    generated_text = [current_word]

    for _ in range(length):
        candidates = {k[1]: v for k, v in bigram_model.items() if k[0] == current_word}
        if not candidates:
            break  # Stop if no valid next word is found
        current_word = max(candidates, key=candidates.get)
        generated_text.append(current_word)
    
    return " ".join(generated_text)

# testing generated text
print("\nGenerated Text:", generate_bigram_text(bigram_probability, "decision", 10))

# Evaluate The Test Sentence
test_sentence = "decision problem is a concept related to algorithms"
test_tokenized_words = [word for word in word_tokenize(test_sentence.lower()) if word.isalnum()]

print("\nEvaluation on Test Sentence:")
print("Test Sentence:", test_sentence)

predicted_words = []
for i in range(len(test_tokenized_words) - 1):  # Iterate through word pairs
    current_word = test_tokenized_words[i]
    actual_next_word = test_tokenized_words[i + 1]
    predicted_next_word = predict_next_word(bigram_probability, current_word)

    predicted_words.append(predicted_next_word)
    print(f"Given '{current_word}', Actual: '{actual_next_word}', Predicted: '{predicted_next_word}'")

# Calculate accuracy of predictions
correct_predictions = sum(1 for i in range(len(predicted_words)) if predicted_words[i] == test_tokenized_words[i + 1])
accuracy = correct_predictions / (len(test_tokenized_words) - 1) * 100
print(f"\nPrediction Accuracy: {accuracy:.2f}%")

# 3. Using a test sentence “The quick brown fox jumps over the lazy dog near the bank of the river.”  OR generate your own test sentence, create a function that will determine the perplexity score for each trained model.
# a.Bigram model perplexity -> Test Sentence “” -> Score:

# Computes bigram perplexity
def compute_bigram_perplexity(bigram_probability, test_sentence):
    tokennized_words = [word for word in word_tokenize(test_sentence.lower()) if word.isalnum()]
    N = len(tokennized_words)
    log_prob_sum = 0

    for i in range(1, N):
        word1, word2 = tokennized_words[i - 1], tokennized_words[i]
        prob = bigram_probability.get((word1, word2), 1e-10)  # Avoid zero probability
        log_prob_sum += math.log2(prob)

    perplexity = 2 ** (-log_prob_sum / N)
    return perplexity

# Test Sentences
test_sentences = [
    "The quick brown fox jumps over the lazy dog near the bank of the river.",
    "In computability theory and computational complexity theory, a decision problem is a computational problem that can be posed as a yes-no question based on the given input values.",
    "A decision problem which can be solved by an algorithm is called decidable."
]

# Computes and Shows the Perplexity Scores
for i, sentence in enumerate(test_sentences, 1):
    perplexity = compute_bigram_perplexity(bigram_probability, sentence)
    print(f"\nBigram Model Perplexity (Sentence: {sentence}): {perplexity:.4f}")
# Out:
# Extracted Training Text (First 1000 Words):
#
# In computability theory and computational complexity theory, a decision problem is a computational problem that can be posed as a yes–no question based on the given input values. An example of a decision problem is deciding with the help of an algorithm whether a given natural number is prime. Another example is the problem, "given two numbers x and y, does x evenly divide y?" A method for solving a decision problem, given in the form of an algorithm, is called a decision procedure for that problem. A decision procedure for the decision problem "given two numbers x and y, does x evenly divide y?" would give the steps for determining whether x evenly divides y. One such algorithm is long division. If the remainder is zero the answer is 'yes', otherwise it is 'no'. A decision problem which can be solved by an algorithm is called decidable. Decision problems typically appear in mathematical questions of decidability, that is, the question of the existence of an effective method to determine the existence of some object or its membership in a set; some of the most important problems in mathematics are undecidable. The field of computational complexity categorizes decidable decision problems by how difficult they are to solve. "Difficult", in this sense, is described in terms of the computational resources needed by the most efficient algorithm for a certain problem. The field of recursion theory, meanwhile, categorizes undecidable decision problems by Turing degree, which is a measure of the noncomputability inherent in any solution. == Definition == A decision problem is a yes-or-no question on an infinite set of inputs. It is traditional to define the decision problem as the set of possible inputs together with the set of inputs for which the answer is yes. These inputs can be natural numbers, but can also be values of some other kind, like binary strings or strings over some other alphabet. The subset of strings for which the problem returns "yes" is a formal language, and often decision problems are defined as formal languages. Using an encoding such as Gödel numbering, any string can be encoded as a natural number, via which a decision problem can be defined as a subset of the natural numbers. Therefore, the algorithm of a decision problem is to compute the characteristic function of a subset of the natural numbers. == Examples == A classic example of a decidable decision problem is the set of prime numbers. It is possible to effectively decide whether a given natural number is prime by testing every possible nontrivial factor. Although much more efficient methods of primality testing are known, the existence of any effective method is enough to establish decidability. == Decidability == A decision problem is decidable or effectively solvable if the set of inputs (or natural numbers) for which the answer is yes is a recursive set. A problem is partially decidable, semidecidable, solvable, or provable if the set of inputs (or natural numbers) for which the answer is yes is a recursively enumerable set. Problems that are not decidable are undecidable. For those it is not possible to create an algorithm, efficient or otherwise, that solves them. The halting problem is an important undecidable decision problem; for more examples, see list of undecidable problems. == Complete problems == Decision problems can be ordered according to many-one reducibility and related to feasible reductions such as polynomial-time reductions. A decision problem P is said to be complete for a set of decision problems S if P is a member of S and every problem in S can be reduced to P. Complete decision problems are used in computational complexity theory to characterize complexity classes of decision problems. For example, the Boolean satisfiability problem is complete for the class NP of decision problems under polynomial-time reducibility. == Function problems == Decision problems are closely related to function problems, which can have answers that ...
# Tokens: ['in', 'computability', 'theory', 'and', 'computational', 'complexity', 'theory', 'a', 'decision', 'problem', 'is', 'a', 'computational', 'problem', 'that', 'can', 'be', 'posed', 'as', 'a', 'question', 'based', 'on', 'the', 'given', 'input', 'values', 'an', 'example', 'of', 'a', 'decision', 'problem', 'is', 'deciding', 'with', 'the', 'help', 'of', 'an', 'algorithm', 'whether', 'a', 'given', 'natural', 'number', 'is', 'prime', 'another', 'example', 'is', 'the', 'problem', 'given', 'two', 'numbers', 'x', 'and', 'y', 'does', 'x', 'evenly', 'divide', 'y', 'a', 'method', 'for', 'solving', 'a', 'decision', 'problem', 'given', 'in', 'the', 'form', 'of', 'an', 'algorithm', 'is', 'called', 'a', 'decision', 'procedure', 'for', 'that', 'problem', 'a', 'decision', 'procedure', 'for', 'the', 'decision', 'problem', 'given', 'two', 'numbers', 'x', 'and', 'y', 'does', 'x', 'evenly', 'divide', 'y', 'would', 'give', 'the', 'steps', 'for', 'determining', 'whether', 'x', 'evenly', 'divides', 'one', 'such', 'algorithm', 'is', 'long', 'division', 'if', 'the', 'remainder', 'is', 'zero', 'the', 'answer', 'is', 'otherwise', 'it', 'is', 'a', 'decision', 'problem', 'which', 'can', 'be', 'solved', 'by', 'an', 'algorithm', 'is', 'called', 'decidable', 'decision', 'problems', 'typically', 'appear', 'in', 'mathematical', 'questions', 'of', 'decidability', 'that', 'is', 'the', 'question', 'of', 'the', 'existence', 'of', 'an', 'effective', 'method', 'to', 'determine', 'the', 'existence', 'of', 'some', 'object', 'or', 'its', 'membership', 'in', 'a', 'set', 'some', 'of', 'the', 'most', 'important', 'problems', 'in', 'mathematics', 'are', 'undecidable', 'the', 'field', 'of', 'computational', 'complexity', 'categorizes', 'decidable', 'decision', 'problems', 'by', 'how', 'difficult', 'they', 'are', 'to', 'solve', 'difficult', 'in', 'this', 'sense', 'is', 'described', 'in', 'terms', 'of', 'the', 'computational', 'resources', 'needed', 'by', 'the', 'most', 'efficient', 'algorithm', 'for', 'a', 'certain', 'problem', 'the', 'field', 'of', 'recursion', 'theory', 'meanwhile', 'categorizes', 'undecidable', 'decision', 'problems', 'by', 'turing', 'degree', 'which', 'is', 'a', 'measure', 'of', 'the', 'noncomputability', 'inherent', 'in', 'any', 'solution', 'definition', 'a', 'decision', 'problem', 'is', 'a', 'question', 'on', 'an', 'infinite', 'set', 'of', 'inputs', 'it', 'is', 'traditional', 'to', 'define', 'the', 'decision', 'problem', 'as', 'the', 'set', 'of', 'possible', 'inputs', 'together', 'with', 'the', 'set', 'of', 'inputs', 'for', 'which', 'the', 'answer', 'is', 'yes', 'these', 'inputs', 'can', 'be', 'natural', 'numbers', 'but', 'can', 'also', 'be', 'values', 'of', 'some', 'other', 'kind', 'like', 'binary', 'strings', 'or', 'strings', 'over', 'some', 'other', 'alphabet', 'the', 'subset', 'of', 'strings', 'for', 'which', 'the', 'problem', 'returns', 'yes', 'is', 'a', 'formal', 'language', 'and', 'often', 'decision', 'problems', 'are', 'defined', 'as', 'formal', 'languages', 'using', 'an', 'encoding', 'such', 'as', 'gödel', 'numbering', 'any', 'string', 'can', 'be', 'encoded', 'as', 'a', 'natural', 'number', 'via', 'which', 'a', 'decision', 'problem', 'can', 'be', 'defined', 'as', 'a', 'subset', 'of', 'the', 'natural', 'numbers', 'therefore', 'the', 'algorithm', 'of', 'a', 'decision', 'problem', 'is', 'to', 'compute', 'the', 'characteristic', 'function', 'of', 'a', 'subset', 'of', 'the', 'natural', 'numbers', 'examples', 'a', 'classic', 'example', 'of', 'a', 'decidable', 'decision', 'problem', 'is', 'the', 'set', 'of', 'prime', 'numbers', 'it', 'is', 'possible', 'to', 'effectively', 'decide', 'whether', 'a', 'given', 'natural', 'number', 'is', 'prime', 'by', 'testing', 'every', 'possible', 'nontrivial', 'factor', 'although', 'much', 'more', 'efficient', 'methods', 'of', 'primality', 'testing', 'are', 'known', 'the', 'existence', 'of', 'any', 'effective', 'method', 'is', 'enough', 'to', 'establish', 'decidability', 'decidability', 'a', 'decision', 'problem', ...
#
# Unigram Counts:
# in: 18
# computability: 1
# theory: 4
# and: 10
# computational: 7
# complexity: 7
# a: 42
# decision: 34
# problem: 36
# is: 49
# that: 7
# can: 11
# be: 14
# posed: 1
# as: 11
# question: 4
# based: 1
# on: 3
# the: 63
# given: 8
# input: 3
# values: 3
# an: 10
# example: 6
# of: 46
# deciding: 1
# with: 3
# help: 1
# algorithm: 7
# whether: 4
# natural: 8
# number: 3
# prime: 3
# another: 1
# two: 3
# numbers: 9
# x: 12
# y: 9
# does: 3
# evenly: 3
# divide: 2
# method: 3
# for: 20
# solving: 1
# form: 1
# called: 3
# procedure: 2
# would: 2
# give: 1
# steps: 1
# determining: 1
# divides: 1
# one: 2
# such: 5
# long: 1
# division: 1
# if: 6
# remainder: 1
# zero: 1
# answer: 6
# otherwise: 2
# it: 6
# which: 12
# solved: 1
# by: 7
# decidable: 8
# problems: 23
# typically: 1
# appear: 1
# mathematical: 1
# questions: 2
# decidability: 3
# existence: 3
# effective: 2
# to: 19
# determine: 1
# some: 5
# object: 1
# or: 10
# its: 2
# membership: 1
# set: 12
# most: 2
# important: 2
# mathematics: 1
# are: 11
# undecidable: 5
# field: 2
# categorizes: 2
# how: 1
# difficult: 2
# they: 1
# solve: 1
# this: 7
# sense: 1
# described: 1
# terms: 1
# resources: 1
# needed: 1
# efficient: 3
# certain: 1
# recursion: 1
# meanwhile: 1
# turing: 1
# degree: 1
# measure: 1
# noncomputability: 1
# inherent: 1
# any: 3
# solution: 1
# definition: 1
# infinite: 1
# inputs: 7
# traditional: 1
# define: 1
# possible: 5
# together: 1
# yes: 4
# these: 1
# but: 1
# also: 1
# other: 2
# kind: 1
# like: 1
# binary: 1
# strings: 3
# over: 1
# alphabet: 1
# subset: 3
# returns: 1
# formal: 2
# language: 1
# often: 2
# defined: 3
# languages: 1
# using: 1
# encoding: 1
# gödel: 1
# numbering: 1
# string: 1
# encoded: 1
# via: 1
# therefore: 1
# compute: 2
# characteristic: 3
# function: 19
# examples: 2
# classic: 1
# effectively: 3
# decide: 1
# testing: 2
# every: 4
# nontrivial: 1
# factor: 1
# although: 1
# much: 1
# more: 4
# methods: 1
# primality: 1
# known: 1
# enough: 1
# establish: 1
# solvable: 3
# recursive: 1
# partially: 1
# semidecidable: 1
# provable: 1
# recursively: 1
# enumerable: 1
# not: 5
# those: 1
# create: 1
# solves: 1
# them: 1
# halting: 1
# see: 1
# list: 1
# complete: 4
# ordered: 1
# according: 1
# reducibility: 2
# related: 2
# feasible: 1
# reductions: 2
# p: 2
# said: 1
# s: 3
# member: 1
# reduced: 1
# used: 2
# characterize: 1
# classes: 1
# boolean: 1
# satisfiability: 1
# class: 1
# np: 1
# under: 1
# closely: 1
# have: 1
# answers: 1
# complex: 1
# than: 3
# simple: 1
# corresponding: 1
# what: 1
# divided: 1
# consists: 1
# partial: 1
# f: 5
# informal: 1
# turned: 1
# into: 3
# just: 1
# graph: 3
# associated: 3
# pairs: 1
# were: 1
# then: 2
# well: 1
# reduction: 4
# respect: 1
# however: 2
# polynomial: 2
# time: 4
# case: 2
# running: 2
# computed: 2
# pair: 1
# when: 1
# computable: 2
# alone: 1
# 2x: 1
# has: 1
# property: 1
# converted: 1
# computing: 1
# liberal: 1
# standard: 1
# sometimes: 1
# functions: 1
# complement: 1
# exactly: 1
# same: 1
# even: 1
# though: 1
# underlying: 1
# may: 1
# considered: 1
# equivalent: 1
# typical: 1
# models: 1
# computation: 1
# optimization: 4
# unlike: 1
# there: 1
# only: 1
# correct: 1
# each: 1
# concerned: 1
# finding: 1
# best: 1
# particular: 1
# arise: 1
# naturally: 1
# many: 2
# applications: 1
# traveling: 1
# salesman: 1
# linear: 1
# programming: 1
# transformed: 1
# considering: 1
# output: 1
# equal: 2
# less: 1
# value: 1
#
# Bigram Counts:
# ('in', 'computability'): 1
# ('computability', 'theory'): 1
# ('theory', 'and'): 1
# ('and', 'computational'): 1
# ('computational', 'complexity'): 5
# ('complexity', 'theory'): 2
# ('theory', 'a'): 1
# ('a', 'decision'): 12
# ('decision', 'problem'): 19
# ('problem', 'is'): 13
# ('is', 'a'): 8
# ('a', 'computational'): 1
# ('computational', 'problem'): 1
# ('problem', 'that'): 1
# ('that', 'can'): 1
# ('can', 'be'): 9
# ('be', 'posed'): 1
# ('posed', 'as'): 1
# ('as', 'a'): 5
# ('a', 'question'): 2
# ('question', 'based'): 1
# ('based', 'on'): 1
# ('on', 'the'): 2
# ('the', 'given'): 1
# ('given', 'input'): 1
# ('input', 'values'): 1
# ('values', 'an'): 1
# ('an', 'example'): 1
# ('example', 'of'): 2
# ('of', 'a'): 7
# P(decision | a) = 0.2857
# P(problem | decision) = 0.5588
# P(is | problem) = 0.3611
# P(a | is) = 0.1633
# P(computational | a) = 0.0238
# P(problem | computational) = 0.1429
# P(that | problem) = 0.0278
# P(can | that) = 0.1429
# P(be | can) = 0.8182
# P(posed | be) = 0.0714
# P(as | posed) = 1.0000
# P(a | as) = 0.4545
# P(question | a) = 0.0476
# P(based | question) = 0.2500
# P(on | based) = 1.0000
# P(the | on) = 0.6667
# P(given | the) = 0.0159
# P(input | given) = 0.1250
# P(values | input) = 0.3333
# P(an | values) = 0.3333
# P(example | an) = 0.1000
# P(of | example) = 0.3333
# P(a | of) = 0.1522
# P(deciding | is) = 0.0204
# P(with | deciding) = 1.0000
# P(the | with) = 0.6667
# P(help | the) = 0.0159
# P(of | help) = 1.0000
# P(an | of) = 0.0870
# P(algorithm | an) = 0.4000
# P(whether | algorithm) = 0.1429
# P(a | whether) = 0.5000
# P(given | a) = 0.0714
# P(natural | given) = 0.2500
# P(number | natural) = 0.3750
# P(is | number) = 0.6667
# P(prime | is) = 0.0408
# P(another | prime) = 0.3333
# P(example | another) = 1.0000
# P(is | example) = 0.1667
# P(the | is) = 0.0816
# P(problem | the) = 0.0317
# P(given | problem) = 0.0833
# P(two | given) = 0.3750
# P(numbers | two) = 1.0000
# P(x | numbers) = 0.3333
# P(and | x) = 0.2500
# P(y | and) = 0.3000
# P(does | y) = 0.2222
# P(x | does) = 0.6667
# P(evenly | x) = 0.2500
# P(divide | evenly) = 0.6667
# P(y | divide) = 1.0000
# P(a | y) = 0.2222
# P(method | a) = 0.0238
# P(for | method) = 0.3333
# P(solving | for) = 0.0500
# P(a | solving) = 1.0000
# P(in | given) = 0.1250
# P(the | in) = 0.0556
# P(form | the) = 0.0159
# P(of | form) = 1.0000
# P(is | algorithm) = 0.4286
# P(called | is) = 0.0408
# P(a | called) = 0.3333
# P(procedure | decision) = 0.0588
# P(for | procedure) = 1.0000
# P(that | for) = 0.0500
# P(problem | that) = 0.1429
# P(a | problem) = 0.0278
# P(the | for) = 0.1500
# P(decision | the) = 0.0635
# P(would | y) = 0.1111
# P(give | would) = 0.5000
# P(the | give) = 1.0000
# P(steps | the) = 0.0159
# P(for | steps) = 1.0000
# P(determining | for) = 0.0500
# P(whether | determining) = 1.0000
# P(x | whether) = 0.2500
# P(divides | evenly) = 0.3333
# P(one | divides) = 1.0000
# P(such | one) = 0.5000
# P(algorithm | such) = 0.2000
# P(long | is) = 0.0204
# P(division | long) = 1.0000
# P(if | division) = 1.0000
# P(the | if) = 0.5000
# P(remainder | the) = 0.0159
# P(is | remainder) = 1.0000
# P(zero | is) = 0.0204
# P(the | zero) = 1.0000
# P(answer | the) = 0.0635
# P(is | answer) = 0.6667
# P(otherwise | is) = 0.0204
# P(it | otherwise) = 0.5000
# P(is | it) = 1.0000
# P(which | problem) = 0.0278
# P(can | which) = 0.1667
# P(solved | be) = 0.0714
# P(by | solved) = 1.0000
# P(an | by) = 0.1429
# P(decidable | called) = 0.3333
# P(decision | decidable) = 0.3750
# P(problems | decision) = 0.3824
# P(typically | problems) = 0.0435
# P(appear | typically) = 1.0000
# P(in | appear) = 1.0000
# P(mathematical | in) = 0.0556
# P(questions | mathematical) = 1.0000
# P(of | questions) = 0.5000
# P(decidability | of) = 0.0217
# P(that | decidability) = 0.3333
# P(is | that) = 0.1429
# P(question | the) = 0.0317
# P(of | question) = 0.5000
# P(the | of) = 0.2174
# P(existence | the) = 0.0476
# P(of | existence) = 1.0000
# P(effective | an) = 0.1000
# P(method | effective) = 1.0000
# P(to | method) = 0.3333
# P(determine | to) = 0.0526
# P(the | determine) = 1.0000
# P(some | of) = 0.0435
# P(object | some) = 0.2000
# P(or | object) = 1.0000
# P(its | or) = 0.1000
# P(membership | its) = 0.5000
# P(in | membership) = 1.0000
# P(a | in) = 0.0556
# P(set | a) = 0.0476
# P(some | set) = 0.0833
# P(of | some) = 0.2000
# P(most | the) = 0.0317
# P(important | most) = 0.5000
# P(problems | important) = 0.5000
# P(in | problems) = 0.0435
# P(mathematics | in) = 0.0556
# P(are | mathematics) = 1.0000
# P(undecidable | are) = 0.1818
# P(the | undecidable) = 0.2000
# P(field | the) = 0.0317
# P(of | field) = 1.0000
# P(computational | of) = 0.0217
# P(categorizes | complexity) = 0.1429
# P(decidable | categorizes) = 0.5000
# P(by | problems) = 0.1304
# P(how | by) = 0.1429
# P(difficult | how) = 1.0000
# P(they | difficult) = 0.5000
# P(are | they) = 1.0000
# P(to | are) = 0.0909
# P(solve | to) = 0.0526
# P(difficult | solve) = 1.0000
# P(in | difficult) = 0.5000
# P(this | in) = 0.0556
# P(sense | this) = 0.1429
# P(is | sense) = 1.0000
# P(described | is) = 0.0204
# P(in | described) = 1.0000
# P(terms | in) = 0.0556
# P(of | terms) = 1.0000
# P(computational | the) = 0.0159
# P(resources | computational) = 0.1429
# P(needed | resources) = 1.0000
# P(by | needed) = 1.0000
# P(the | by) = 0.1429
# P(efficient | most) = 0.5000
# P(algorithm | efficient) = 0.3333
# P(for | algorithm) = 0.1429
# P(a | for) = 0.1000
# P(certain | a) = 0.0238
# P(problem | certain) = 1.0000
# P(the | problem) = 0.0556
# P(recursion | of) = 0.0217
# P(theory | recursion) = 1.0000
# P(meanwhile | theory) = 0.2500
# P(categorizes | meanwhile) = 1.0000
# P(undecidable | categorizes) = 0.5000
# P(decision | undecidable) = 0.4000
# P(turing | by) = 0.1429
# P(degree | turing) = 1.0000
# P(which | degree) = 1.0000
# P(is | which) = 0.0833
# P(measure | a) = 0.0238
# P(of | measure) = 1.0000
# P(noncomputability | the) = 0.0159
# P(inherent | noncomputability) = 1.0000
# P(in | inherent) = 1.0000
# P(any | in) = 0.0556
# P(solution | any) = 0.3333
# P(definition | solution) = 1.0000
# P(a | definition) = 1.0000
# P(on | question) = 0.2500
# P(an | on) = 0.3333
# P(infinite | an) = 0.1000
# P(set | infinite) = 1.0000
# P(of | set) = 0.6667
# P(inputs | of) = 0.0870
# P(it | inputs) = 0.1429
# P(traditional | is) = 0.0204
# P(to | traditional) = 1.0000
# P(define | to) = 0.0526
# P(the | define) = 1.0000
# P(as | problem) = 0.0278
# P(the | as) = 0.1818
# P(set | the) = 0.1111
# P(possible | of) = 0.0217
# P(inputs | possible) = 0.2000
# P(together | inputs) = 0.1429
# P(with | together) = 1.0000
# P(for | inputs) = 0.2857
# P(which | for) = 0.3000
# P(the | which) = 0.3333
# P(yes | is) = 0.0612
# P(these | yes) = 0.2500
# P(inputs | these) = 1.0000
# P(can | inputs) = 0.1429
# P(natural | be) = 0.0714
# P(numbers | natural) = 0.6250
# P(but | numbers) = 0.1111
# P(can | but) = 1.0000
# P(also | can) = 0.0909
# P(be | also) = 1.0000
# P(values | be) = 0.0714
# P(of | values) = 0.6667
# P(other | some) = 0.4000
# P(kind | other) = 0.5000
# P(like | kind) = 1.0000
# P(binary | like) = 1.0000
# P(strings | binary) = 1.0000
# P(or | strings) = 0.3333
# P(strings | or) = 0.1000
# P(over | strings) = 0.3333
# P(some | over) = 1.0000
# P(alphabet | other) = 0.5000
# P(the | alphabet) = 1.0000
# P(subset | the) = 0.0159
# P(of | subset) = 1.0000
# P(strings | of) = 0.0217
# P(for | strings) = 0.3333
# P(returns | problem) = 0.0278
# P(yes | returns) = 1.0000
# P(is | yes) = 0.7500
# P(formal | a) = 0.0238
# P(language | formal) = 0.5000
# P(and | language) = 1.0000
# P(often | and) = 0.1000
# P(decision | often) = 0.5000
# P(are | problems) = 0.2174
# P(defined | are) = 0.0909
# P(as | defined) = 0.6667
# P(formal | as) = 0.0909
# P(languages | formal) = 0.5000
# P(using | languages) = 1.0000
# P(an | using) = 1.0000
# P(encoding | an) = 0.1000
# P(such | encoding) = 1.0000
# P(as | such) = 0.6000
# P(gödel | as) = 0.0909
# P(numbering | gödel) = 1.0000
# P(any | numbering) = 1.0000
# P(string | any) = 0.3333
# P(can | string) = 1.0000
# P(encoded | be) = 0.0714
# P(as | encoded) = 1.0000
# P(natural | a) = 0.0238
# P(via | number) = 0.3333
# P(which | via) = 1.0000
# P(a | which) = 0.0833
# P(can | problem) = 0.0833
# P(defined | be) = 0.0714
# P(subset | a) = 0.0476
# P(natural | the) = 0.0317
# P(therefore | numbers) = 0.1111
# P(the | therefore) = 1.0000
# P(algorithm | the) = 0.0159
# P(of | algorithm) = 0.1429
# P(to | is) = 0.0408
# P(compute | to) = 0.1053
# P(the | compute) = 1.0000
# P(characteristic | the) = 0.0476
# P(function | characteristic) = 0.6667
# P(of | function) = 0.2105
# P(examples | numbers) = 0.1111
# P(a | examples) = 0.5000
# P(classic | a) = 0.0238
# P(example | classic) = 1.0000
# P(decidable | a) = 0.0238
# P(prime | of) = 0.0217
# P(numbers | prime) = 0.3333
# P(it | numbers) = 0.1111
# P(possible | is) = 0.0408
# P(to | possible) = 0.4000
# P(effectively | to) = 0.0526
# P(decide | effectively) = 0.3333
# P(whether | decide) = 1.0000
# P(by | prime) = 0.3333
# P(testing | by) = 0.1429
# P(every | testing) = 0.5000
# P(possible | every) = 0.2500
# P(nontrivial | possible) = 0.2000
# P(factor | nontrivial) = 1.0000
# P(although | factor) = 1.0000
# P(much | although) = 1.0000
# P(more | much) = 1.0000
# P(efficient | more) = 0.2500
# P(methods | efficient) = 0.3333
# P(of | methods) = 1.0000
# P(primality | of) = 0.0217
# P(testing | primality) = 1.0000
# P(are | testing) = 0.5000
# P(known | are) = 0.0909
# P(the | known) = 1.0000
# P(any | of) = 0.0217
# P(effective | any) = 0.3333
# P(is | method) = 0.3333
# P(enough | is) = 0.0204
# P(to | enough) = 1.0000
# P(establish | to) = 0.0526
# P(decidability | establish) = 1.0000
# P(decidability | decidability) = 0.3333
# P(a | decidability) = 0.3333
# P(decidable | is) = 0.0408
# P(or | decidable) = 0.1250
# P(effectively | or) = 0.1000
# P(solvable | effectively) = 0.6667
# P(if | solvable) = 0.3333
# P(or | inputs) = 0.2857
# P(natural | or) = 0.2000
# P(for | numbers) = 0.2222
# P(recursive | a) = 0.0238
# P(set | recursive) = 1.0000
# P(a | set) = 0.0833
# P(problem | a) = 0.0238
# P(partially | is) = 0.0204
# P(decidable | partially) = 1.0000
# P(semidecidable | decidable) = 0.1250
# P(solvable | semidecidable) = 1.0000
# P(or | solvable) = 0.3333
# P(provable | or) = 0.1000
# P(if | provable) = 1.0000
# P(recursively | a) = 0.0238
# P(enumerable | recursively) = 1.0000
# P(set | enumerable) = 1.0000
# P(problems | set) = 0.0833
# P(that | problems) = 0.0435
# P(are | that) = 0.2857
# P(not | are) = 0.0909
# P(decidable | not) = 0.2000
# P(are | decidable) = 0.1250
# P(for | undecidable) = 0.2000
# P(those | for) = 0.0500
# P(it | those) = 1.0000
# P(not | is) = 0.0408
# P(possible | not) = 0.2000
# P(create | to) = 0.0526
# P(an | create) = 1.0000
# P(efficient | algorithm) = 0.1429
# P(or | efficient) = 0.3333
# P(otherwise | or) = 0.1000
# P(that | otherwise) = 0.5000
# P(solves | that) = 0.1429
# P(them | solves) = 1.0000
# P(the | them) = 1.0000
# P(halting | the) = 0.0159
# P(problem | halting) = 1.0000
# P(an | is) = 0.0204
# P(important | an) = 0.1000
# P(undecidable | important) = 0.5000
# P(for | problem) = 0.0278
# P(more | for) = 0.0500
# P(examples | more) = 0.2500
# P(see | examples) = 0.5000
# P(list | see) = 1.0000
# P(of | list) = 1.0000
# P(undecidable | of) = 0.0217
# P(problems | undecidable) = 0.2000
# P(complete | problems) = 0.0435
# P(problems | complete) = 0.2500
# P(decision | problems) = 0.0870
# P(can | problems) = 0.0435
# P(ordered | be) = 0.0714
# P(according | ordered) = 1.0000
# P(to | according) = 1.0000
# P(reducibility | to) = 0.0526
# P(and | reducibility) = 0.5000
# P(related | and) = 0.1000
# P(to | related) = 1.0000
# P(feasible | to) = 0.0526
# P(reductions | feasible) = 1.0000
# P(such | reductions) = 0.5000
# P(reductions | as) = 0.0909
# P(a | reductions) = 0.5000
# P(p | problem) = 0.0278
# P(is | p) = 1.0000
# P(said | is) = 0.0204
# P(to | said) = 1.0000
# P(be | to) = 0.1053
# P(complete | be) = 0.0714
# P(for | complete) = 0.5000
# P(decision | of) = 0.0652
# P(s | problems) = 0.0435
# P(if | s) = 0.3333
# P(p | if) = 0.1667
# P(member | a) = 0.0238
# P(of | member) = 1.0000
# P(s | of) = 0.0217
# P(and | s) = 0.3333
# P(every | and) = 0.1000
# P(problem | every) = 0.2500
# P(in | problem) = 0.0278
# P(s | in) = 0.0556
# P(can | s) = 0.3333
# P(reduced | be) = 0.0714
# P(to | reduced) = 1.0000
# P(complete | to) = 0.0526
# P(decision | complete) = 0.2500
# P(used | are) = 0.0909
# P(in | used) = 1.0000
# P(computational | in) = 0.1111
# P(to | theory) = 0.2500
# P(characterize | to) = 0.0526
# P(complexity | characterize) = 1.0000
# P(classes | complexity) = 0.1429
# P(of | classes) = 1.0000
# P(for | problems) = 0.0870
# P(example | for) = 0.1500
# P(the | example) = 0.3333
# P(boolean | the) = 0.0159
# P(satisfiability | boolean) = 1.0000
# P(problem | satisfiability) = 1.0000
# P(complete | is) = 0.0204
# P(class | the) = 0.0159
# P(np | class) = 1.0000
# P(of | np) = 1.0000
# P(under | problems) = 0.0435
# P(reducibility | under) = 1.0000
# P(function | reducibility) = 0.5000
# P(problems | function) = 0.1053
# P(closely | are) = 0.0909
# P(related | closely) = 1.0000
# P(function | to) = 0.0526
# P(which | problems) = 0.0435
# P(have | can) = 0.0909
# P(answers | have) = 1.0000
# P(that | answers) = 1.0000
# P(more | are) = 0.0909
# P(complex | more) = 0.2500
# P(than | complex) = 1.0000
# P(a | than) = 0.3333
# P(simple | a) = 0.0238
# P(or | simple) = 1.0000
# P(a | or) = 0.1000
# P(corresponding | a) = 0.0238
# P(function | corresponding) = 1.0000
# P(problem | function) = 0.2632
# P(given | is) = 0.0204
# P(what | y) = 0.1111
# P(is | what) = 1.0000
# P(x | is) = 0.0204
# P(divided | x) = 0.0833
# P(by | divided) = 1.0000
# P(y | by) = 0.1429
# P(function | a) = 0.1190
# P(consists | problem) = 0.0278
# P(of | consists) = 1.0000
# P(partial | a) = 0.0238
# P(function | partial) = 1.0000
# P(f | function) = 0.1579
# P(the | f) = 0.2000
# P(informal | the) = 0.0159
# P(problem | informal) = 1.0000
# P(values | the) = 0.0159
# P(f | of) = 0.0217
# P(on | f) = 0.2000
# P(inputs | the) = 0.0159
# P(it | which) = 0.0833
# P(defined | is) = 0.0204
# P(every | defined) = 0.3333
# P(function | every) = 0.2500
# P(turned | be) = 0.0714
# P(into | turned) = 1.0000
# P(a | into) = 0.3333
# P(just | is) = 0.0204
# P(the | just) = 1.0000
# P(graph | the) = 0.0476
# P(of | graph) = 1.0000
# P(associated | the) = 0.0317
# P(function | associated) = 0.3333
# P(the | function) = 0.0526
# P(is | f) = 0.2000
# P(pairs | of) = 0.0217
# P(x | pairs) = 1.0000
# P(y | x) = 0.2500
# P(such | y) = 0.1111
# P(that | such) = 0.2000
# P(f | that) = 0.1429
# P(x | f) = 0.4000
# P(if | y) = 0.1111
# P(this | if) = 0.3333
# P(decision | this) = 0.1429
# P(were | problem) = 0.0278
# P(effectively | were) = 1.0000
# P(then | solvable) = 0.3333
# P(the | then) = 1.0000
# P(function | the) = 0.0635
# P(would | problem) = 0.0278
# P(be | would) = 0.5000
# P(as | be) = 0.0714
# P(well | as) = 0.0909
# P(this | well) = 1.0000
# P(reduction | this) = 0.2857
# P(does | reduction) = 0.2500
# P(not | does) = 0.3333
# P(respect | not) = 0.2000
# P(computational | respect) = 1.0000
# P(however | complexity) = 0.1429
# P(for | however) = 0.5000
# P(it | example) = 0.1667
# P(for | possible) = 0.2000
# P(to | function) = 0.0526
# P(decidable | be) = 0.0714
# P(in | decidable) = 0.1250
# P(polynomial | in) = 0.1111
# P(time | polynomial) = 1.0000
# P(in | time) = 0.5000
# P(which | in) = 0.1111
# P(case | which) = 0.1667
# P(running | case) = 1.0000
# P(time | running) = 1.0000
# P(is | time) = 0.5000
# P(computed | is) = 0.0408
# P(as | computed) = 1.0000
# P(pair | the) = 0.0159
# P(x | pair) = 1.0000
# P(when | y) = 0.1111
# P(the | when) = 1.0000
# P(is | function) = 0.1053
# P(computable | not) = 0.2000
# P(in | computable) = 0.5000
# P(x | of) = 0.0217
# P(alone | x) = 0.0833
# P(the | alone) = 1.0000
# P(2x | x) = 0.0833
# P(has | 2x) = 1.0000
# P(this | has) = 1.0000
# P(property | this) = 0.1429
# P(every | property) = 1.0000
# P(decision | every) = 0.2500
# P(converted | be) = 0.0714
# P(into | converted) = 1.0000
# P(the | into) = 0.3333
# P(of | problem) = 0.0278
# P(computing | of) = 0.0217
# P(the | computing) = 1.0000
# P(associated | set) = 0.0833
# P(to | associated) = 0.3333
# P(the | to) = 0.0526
# P(if | problem) = 0.0278
# P(function | this) = 0.1429
# P(computable | is) = 0.0204
# P(then | computable) = 0.5000
# P(decision | associated) = 0.3333
# P(however | decidable) = 0.1250
# P(this | however) = 0.5000
# P(is | reduction) = 0.2500
# P(more | is) = 0.0204
# P(liberal | more) = 0.2500
# P(than | liberal) = 1.0000
# P(the | than) = 0.3333
# P(standard | the) = 0.0159
# P(reduction | standard) = 1.0000
# P(used | reduction) = 0.2500
# P(sometimes | complexity) = 0.1429
# P(called | sometimes) = 1.0000
# P(reduction | called) = 0.3333
# P(for | reduction) = 0.2500
# P(complexity | the) = 0.0159
# P(of | complexity) = 0.1429
# P(functions | characteristic) = 0.3333
# P(of | functions) = 1.0000
# P(problem | an) = 0.1000
# P(and | problem) = 0.0556
# P(its | and) = 0.1000
# P(complement | its) = 0.5000
# P(is | complement) = 1.0000
# P(exactly | is) = 0.0204
# P(the | exactly) = 1.0000
# P(same | the) = 0.0159
# P(even | same) = 1.0000
# P(though | even) = 1.0000
# P(the | though) = 1.0000
# P(underlying | the) = 0.0159
# P(decision | underlying) = 1.0000
# P(may | problems) = 0.0435
# P(not | may) = 1.0000
# P(be | not) = 0.2000
# P(considered | be) = 0.0714
# P(equivalent | considered) = 1.0000
# P(in | equivalent) = 1.0000
# P(some | in) = 0.0556
# P(typical | some) = 0.2000
# P(models | typical) = 1.0000
# P(of | models) = 1.0000
# P(computation | of) = 0.0217
# P(optimization | computation) = 1.0000
# P(problems | optimization) = 1.0000
# P(unlike | problems) = 0.0435
# P(decision | unlike) = 1.0000
# P(there | which) = 0.0833
# P(is | there) = 1.0000
# P(only | is) = 0.0204
# P(one | only) = 1.0000
# P(correct | one) = 0.5000
# P(answer | correct) = 1.0000
# P(for | answer) = 0.1667
# P(each | for) = 0.0500
# P(input | each) = 1.0000
# P(optimization | input) = 0.6667
# P(concerned | are) = 0.0909
# P(with | concerned) = 1.0000
# P(finding | with) = 0.3333
# P(the | finding) = 1.0000
# P(best | the) = 0.0159
# P(answer | best) = 1.0000
# P(to | answer) = 0.1667
# P(a | to) = 0.1053
# P(particular | a) = 0.0238
# P(input | particular) = 1.0000
# P(arise | problems) = 0.0435
# P(naturally | arise) = 1.0000
# P(in | naturally) = 1.0000
# P(many | in) = 0.0556
# P(applications | many) = 0.5000
# P(such | applications) = 1.0000
# P(traveling | the) = 0.0159
# P(salesman | traveling) = 1.0000
# P(problem | salesman) = 1.0000
# P(many | and) = 0.1000
# P(questions | many) = 0.5000
# P(in | questions) = 0.5000
# P(linear | in) = 0.0556
# P(programming | linear) = 1.0000
# P(function | programming) = 1.0000
# P(and | function) = 0.0526
# P(optimization | and) = 0.1000
# P(often | are) = 0.0909
# P(transformed | often) = 0.5000
# P(into | transformed) = 1.0000
# P(decision | into) = 0.3333
# P(considering | by) = 0.1429
# P(the | considering) = 1.0000
# P(whether | of) = 0.0217
# P(the | whether) = 0.2500
# P(output | the) = 0.0159
# P(is | output) = 1.0000
# P(equal | is) = 0.0204
# P(to | equal) = 1.0000
# P(or | to) = 0.0526
# P(less | or) = 0.1000
# P(than | less) = 1.0000
# P(or | than) = 0.3333
# P(equal | or) = 0.1000
# P(value | given) = 0.1250
# P(this | value) = 1.0000
#
# Predicted next word after 'problem': is
#
# Generated Text: decision problem is a decision problem is a decision problem is
#
# Evaluation on Test Sentence:
# Test Sentence: decision problem is a concept related to algorithms
# Given 'decision', Actual: 'problem', Predicted: 'problem'
# Given 'problem', Actual: 'is', Predicted: 'is'
# Given 'is', Actual: 'a', Predicted: 'a'
# Given 'a', Actual: 'concept', Predicted: 'decision'
# Given 'concept', Actual: 'related', Predicted: 'None'
# Given 'related', Actual: 'to', Predicted: 'to'
# Given 'to', Actual: 'algorithms', Predicted: 'compute'
#
# Prediction Accuracy: 57.14%
#
# Bigram Model Perplexity (Sentence: The quick brown fox jumps over the lazy dog near the bank of the river.): 513866755.6265
#
# Bigram Model Perplexity (Sentence: In computability theory and computational complexity theory, a decision problem is a computational problem that can be posed as a yes-no question based on the given input values.): 4.6027
#
# Bigram Model Perplexity (Sentence: A decision problem which can be solved by an algorithm is called decidable.): 4.0107

# %%
import wikipedia
from nltk import trigrams
from nltk.tokenize import word_tokenize
from collections import Counter
import string
import math

# 1. Use the Wikipedia python module and access any topic, as you will use that as your corpus, with a word limit of 1000 words. We chose Decision Problem.
# Fetch from Wikipedia page
# Fetch Wikipedia page
wikipedia_page = wikipedia.page("Decision problem")

# Extract first 1000 words
training_text = ' '.join(wikipedia_page.content.split()[:1000])  # Limit to 1000 words

# Display extracted text
print("Extracted Training Text (First 1000 Words):\n")
print(training_text)

# 2. Train a Trigram Model
# Tokenization - Converts text to lowercase, tokenizes words, and removes punctuation
tokennized_words = [word for word in word_tokenize(training_text.lower()) if word.isalnum()]
print("Tokens:", tokennized_words, "\n")

# Counts of Unigrams and Trigrams
unigram_frequency = Counter(tokennized_words) 
trigram_frequency = Counter(trigrams(tokennized_words))

# Show Unigram Counts
print("Unigram Counts:")
for unigram, count in unigram_frequency.items():
    print(f"{unigram}: {count}")

# Show Trigram Counts
print("\nTrigram Counts:")
for trigram, count in trigram_frequency.items():
    print(f"{trigram}: {count}")

# Computes trigram probabilities
print("\nTrigram Probabilities:")
def compute_trigram_probabilities(tokennized_words):
    bigram_frequency = Counter(zip(tokennized_words[:-1], tokennized_words[1:]))
    trigram_probability = {trigram: count / bigram_frequency[(trigram[0], trigram[1])] 
                     for trigram, count in trigram_frequency.items() if (trigram[0], trigram[1]) in bigram_frequency}
    return trigram_probability

# Train the trigram model
trigram_probability = compute_trigram_probabilities(tokennized_words)

# Show Trigram Probabilities
for trigram, prob in trigram_probability.items():
    print(f"P({trigram[2]} | {trigram[0]}, {trigram[1]}) = {prob:.4f}")

# Predict next word
def predict_next_word(trigram_probability, first_word, second_word):
    candidates = {k[2]: v for k, v in trigram_probability.items() if k[0] == first_word and k[1] == second_word}
    return max(candidates, key=candidates.get) if candidates else None

# Predict Test word
predicted_next_word = predict_next_word(trigram_probability, "decision", "problem")
print(f"\nPredicted next word after 'decision problem': {predicted_next_word}")

# Generate text
def generate_trigram_text(trigram_model, start_words, length=10):
    first_word, second_word = start_words.lower().split()
    generated_text = [first_word, second_word]

    for _ in range(length):
        candidates = {k[2]: v for k, v in trigram_model.items() if k[0] == first_word and k[1] == second_word}
        if not candidates:
            break  # Stop if no valid next word is found
        next_word = max(candidates, key=candidates.get)
        generated_text.append(next_word)
        first_word, second_word = second_word, next_word  # Move to the next pair
    
    return " ".join(generated_text)

# testing generated text
print("\nGenerated Text:", generate_trigram_text(trigram_probability, "decision problem", 10))

# Evaluate The Test Sentence
test_sentence = "decision problem is a concept related to algorithms"
test_tokenized_words = [word for word in word_tokenize(test_sentence.lower()) if word.isalnum()]

print("\nEvaluation on Test Sentence:")
print("Test Sentence:", test_sentence)

predicted_words = []
for i in range(len(test_tokenized_words) - 2):  # Iterate through word triplets
    first_word = test_tokenized_words[i]
    second_word = test_tokenized_words[i + 1]
    actual_next_word = test_tokenized_words[i + 2]
    predicted_next_word = predict_next_word(trigram_probability, first_word, second_word)

    predicted_words.append(predicted_next_word)
    print(f"Given '{first_word} {second_word}', Actual: '{actual_next_word}', Predicted: '{predicted_next_word}'")

# Calculate accuracy of predictions
correct_predictions = sum(1 for i in range(len(predicted_words)) if predicted_words[i] == test_tokenized_words[i + 2])
accuracy = correct_predictions / (len(test_tokenized_words) - 2) * 100
print(f"\nPrediction Accuracy: {accuracy:.2f}%")


# 3 Using a test sentence “The quick brown fox jumps over the lazy dog near the bank of the river.” OR generate your own test sentence, create a function that will determine the perplexity score for each trained model.
# b.Trigram model perplexity -> Test Sentence “” -> Score:

# Function to compute trigram perplexity
def compute_trigram_perplexity(trigram_probability, test_sentence):
    tokennized_words = [word for word in word_tokenize(test_sentence.lower()) if word.isalnum()]
    N = len(tokennized_words)
    log_prob_sum = 0

    for i in range(2, N):
        word1, word2, word3 = tokennized_words[i - 2], tokennized_words[i - 1], tokennized_words[i]
        prob = trigram_probability.get((word1, word2, word3), 1e-10)  # Avoid zero probability
        log_prob_sum += math.log2(prob)

    perplexity = 2 ** (-log_prob_sum / N)
    return perplexity

# Test Sentences
test_sentences = [
    "The quick brown fox jumps over the lazy dog near the bank of the river.",
    "In computability theory and computational complexity theory, a decision problem is a computational problem that can be posed as a yes-no question based on the given input values.",
    "A decision problem which can be solved by an algorithm is called decidable."
]

# Compute and Shows the Perplexity Scores
for i, sentence in enumerate(test_sentences, 1):
    perplexity = compute_trigram_perplexity(trigram_probability, sentence)
    print(f"\nTrigram Model Perplexity (Sentence: {sentence}):  {perplexity:.4f}")
# Out:
# Extracted Training Text (First 1000 Words):
#
# In computability theory and computational complexity theory, a decision problem is a computational problem that can be posed as a yes–no question based on the given input values. An example of a decision problem is deciding with the help of an algorithm whether a given natural number is prime. Another example is the problem, "given two numbers x and y, does x evenly divide y?" A method for solving a decision problem, given in the form of an algorithm, is called a decision procedure for that problem. A decision procedure for the decision problem "given two numbers x and y, does x evenly divide y?" would give the steps for determining whether x evenly divides y. One such algorithm is long division. If the remainder is zero the answer is 'yes', otherwise it is 'no'. A decision problem which can be solved by an algorithm is called decidable. Decision problems typically appear in mathematical questions of decidability, that is, the question of the existence of an effective method to determine the existence of some object or its membership in a set; some of the most important problems in mathematics are undecidable. The field of computational complexity categorizes decidable decision problems by how difficult they are to solve. "Difficult", in this sense, is described in terms of the computational resources needed by the most efficient algorithm for a certain problem. The field of recursion theory, meanwhile, categorizes undecidable decision problems by Turing degree, which is a measure of the noncomputability inherent in any solution. == Definition == A decision problem is a yes-or-no question on an infinite set of inputs. It is traditional to define the decision problem as the set of possible inputs together with the set of inputs for which the answer is yes. These inputs can be natural numbers, but can also be values of some other kind, like binary strings or strings over some other alphabet. The subset of strings for which the problem returns "yes" is a formal language, and often decision problems are defined as formal languages. Using an encoding such as Gödel numbering, any string can be encoded as a natural number, via which a decision problem can be defined as a subset of the natural numbers. Therefore, the algorithm of a decision problem is to compute the characteristic function of a subset of the natural numbers. == Examples == A classic example of a decidable decision problem is the set of prime numbers. It is possible to effectively decide whether a given natural number is prime by testing every possible nontrivial factor. Although much more efficient methods of primality testing are known, the existence of any effective method is enough to establish decidability. == Decidability == A decision problem is decidable or effectively solvable if the set of inputs (or natural numbers) for which the answer is yes is a recursive set. A problem is partially decidable, semidecidable, solvable, or provable if the set of inputs (or natural numbers) for which the answer is yes is a recursively enumerable set. Problems that are not decidable are undecidable. For those it is not possible to create an algorithm, efficient or otherwise, that solves them. The halting problem is an important undecidable decision problem; for more examples, see list of undecidable problems. == Complete problems == Decision problems can be ordered according to many-one reducibility and related to feasible reductions such as polynomial-time reductions. A decision problem P is said to be complete for a set of decision problems S if P is a member of S and every problem in S can be reduced to P. Complete decision problems are used in computational complexity theory to characterize complexity classes of decision problems. For example, the Boolean satisfiability problem is complete for the class NP of decision problems under polynomial-time reducibility. == Function problems == Decision problems are closely related to function problems, which can have answers that ...
# Tokens: ['in', 'computability', 'theory', 'and', 'computational', 'complexity', 'theory', 'a', 'decision', 'problem', 'is', 'a', 'computational', 'problem', 'that', 'can', 'be', 'posed', 'as', 'a', 'question', 'based', 'on', 'the', 'given', 'input', 'values', 'an', 'example', 'of', 'a', 'decision', 'problem', 'is', 'deciding', 'with', 'the', 'help', 'of', 'an', 'algorithm', 'whether', 'a', 'given', 'natural', 'number', 'is', 'prime', 'another', 'example', 'is', 'the', 'problem', 'given', 'two', 'numbers', 'x', 'and', 'y', 'does', 'x', 'evenly', 'divide', 'y', 'a', 'method', 'for', 'solving', 'a', 'decision', 'problem', 'given', 'in', 'the', 'form', 'of', 'an', 'algorithm', 'is', 'called', 'a', 'decision', 'procedure', 'for', 'that', 'problem', 'a', 'decision', 'procedure', 'for', 'the', 'decision', 'problem', 'given', 'two', 'numbers', 'x', 'and', 'y', 'does', 'x', 'evenly', 'divide', 'y', 'would', 'give', 'the', 'steps', 'for', 'determining', 'whether', 'x', 'evenly', 'divides', 'one', 'such', 'algorithm', 'is', 'long', 'division', 'if', 'the', 'remainder', 'is', 'zero', 'the', 'answer', 'is', 'otherwise', 'it', 'is', 'a', 'decision', 'problem', 'which', 'can', 'be', 'solved', 'by', 'an', 'algorithm', 'is', 'called', 'decidable', 'decision', 'problems', 'typically', 'appear', 'in', 'mathematical', 'questions', 'of', 'decidability', 'that', 'is', 'the', 'question', 'of', 'the', 'existence', 'of', 'an', 'effective', 'method', 'to', 'determine', 'the', 'existence', 'of', 'some', 'object', 'or', 'its', 'membership', 'in', 'a', 'set', 'some', 'of', 'the', 'most', 'important', 'problems', 'in', 'mathematics', 'are', 'undecidable', 'the', 'field', 'of', 'computational', 'complexity', 'categorizes', 'decidable', 'decision', 'problems', 'by', 'how', 'difficult', 'they', 'are', 'to', 'solve', 'difficult', 'in', 'this', 'sense', 'is', 'described', 'in', 'terms', 'of', 'the', 'computational', 'resources', 'needed', 'by', 'the', 'most', 'efficient', 'algorithm', 'for', 'a', 'certain', 'problem', 'the', 'field', 'of', 'recursion', 'theory', 'meanwhile', 'categorizes', 'undecidable', 'decision', 'problems', 'by', 'turing', 'degree', 'which', 'is', 'a', 'measure', 'of', 'the', 'noncomputability', 'inherent', 'in', 'any', 'solution', 'definition', 'a', 'decision', 'problem', 'is', 'a', 'question', 'on', 'an', 'infinite', 'set', 'of', 'inputs', 'it', 'is', 'traditional', 'to', 'define', 'the', 'decision', 'problem', 'as', 'the', 'set', 'of', 'possible', 'inputs', 'together', 'with', 'the', 'set', 'of', 'inputs', 'for', 'which', 'the', 'answer', 'is', 'yes', 'these', 'inputs', 'can', 'be', 'natural', 'numbers', 'but', 'can', 'also', 'be', 'values', 'of', 'some', 'other', 'kind', 'like', 'binary', 'strings', 'or', 'strings', 'over', 'some', 'other', 'alphabet', 'the', 'subset', 'of', 'strings', 'for', 'which', 'the', 'problem', 'returns', 'yes', 'is', 'a', 'formal', 'language', 'and', 'often', 'decision', 'problems', 'are', 'defined', 'as', 'formal', 'languages', 'using', 'an', 'encoding', 'such', 'as', 'gödel', 'numbering', 'any', 'string', 'can', 'be', 'encoded', 'as', 'a', 'natural', 'number', 'via', 'which', 'a', 'decision', 'problem', 'can', 'be', 'defined', 'as', 'a', 'subset', 'of', 'the', 'natural', 'numbers', 'therefore', 'the', 'algorithm', 'of', 'a', 'decision', 'problem', 'is', 'to', 'compute', 'the', 'characteristic', 'function', 'of', 'a', 'subset', 'of', 'the', 'natural', 'numbers', 'examples', 'a', 'classic', 'example', 'of', 'a', 'decidable', 'decision', 'problem', 'is', 'the', 'set', 'of', 'prime', 'numbers', 'it', 'is', 'possible', 'to', 'effectively', 'decide', 'whether', 'a', 'given', 'natural', 'number', 'is', 'prime', 'by', 'testing', 'every', 'possible', 'nontrivial', 'factor', 'although', 'much', 'more', 'efficient', 'methods', 'of', 'primality', 'testing', 'are', 'known', 'the', 'existence', 'of', 'any', 'effective', 'method', 'is', 'enough', 'to', 'establish', 'decidability', 'decidability', 'a', 'decision', 'problem', ...
#
# Unigram Counts:
# in: 18
# computability: 1
# theory: 4
# and: 10
# computational: 7
# complexity: 7
# a: 42
# decision: 34
# problem: 36
# is: 49
# that: 7
# can: 11
# be: 14
# posed: 1
# as: 11
# question: 4
# based: 1
# on: 3
# the: 63
# given: 8
# input: 3
# values: 3
# an: 10
# example: 6
# of: 46
# deciding: 1
# with: 3
# help: 1
# algorithm: 7
# whether: 4
# natural: 8
# number: 3
# prime: 3
# another: 1
# two: 3
# numbers: 9
# x: 12
# y: 9
# does: 3
# evenly: 3
# divide: 2
# method: 3
# for: 20
# solving: 1
# form: 1
# called: 3
# procedure: 2
# would: 2
# give: 1
# steps: 1
# determining: 1
# divides: 1
# one: 2
# such: 5
# long: 1
# division: 1
# if: 6
# remainder: 1
# zero: 1
# answer: 6
# otherwise: 2
# it: 6
# which: 12
# solved: 1
# by: 7
# decidable: 8
# problems: 23
# typically: 1
# appear: 1
# mathematical: 1
# questions: 2
# decidability: 3
# existence: 3
# effective: 2
# to: 19
# determine: 1
# some: 5
# object: 1
# or: 10
# its: 2
# membership: 1
# set: 12
# most: 2
# important: 2
# mathematics: 1
# are: 11
# undecidable: 5
# field: 2
# categorizes: 2
# how: 1
# difficult: 2
# they: 1
# solve: 1
# this: 7
# sense: 1
# described: 1
# terms: 1
# resources: 1
# needed: 1
# efficient: 3
# certain: 1
# recursion: 1
# meanwhile: 1
# turing: 1
# degree: 1
# measure: 1
# noncomputability: 1
# inherent: 1
# any: 3
# solution: 1
# definition: 1
# infinite: 1
# inputs: 7
# traditional: 1
# define: 1
# possible: 5
# together: 1
# yes: 4
# these: 1
# but: 1
# also: 1
# other: 2
# kind: 1
# like: 1
# binary: 1
# strings: 3
# over: 1
# alphabet: 1
# subset: 3
# returns: 1
# formal: 2
# language: 1
# often: 2
# defined: 3
# languages: 1
# using: 1
# encoding: 1
# gödel: 1
# numbering: 1
# string: 1
# encoded: 1
# via: 1
# therefore: 1
# compute: 2
# characteristic: 3
# function: 19
# examples: 2
# classic: 1
# effectively: 3
# decide: 1
# testing: 2
# every: 4
# nontrivial: 1
# factor: 1
# although: 1
# much: 1
# more: 4
# methods: 1
# primality: 1
# known: 1
# enough: 1
# establish: 1
# solvable: 3
# recursive: 1
# partially: 1
# semidecidable: 1
# provable: 1
# recursively: 1
# enumerable: 1
# not: 5
# those: 1
# create: 1
# solves: 1
# them: 1
# halting: 1
# see: 1
# list: 1
# complete: 4
# ordered: 1
# according: 1
# reducibility: 2
# related: 2
# feasible: 1
# reductions: 2
# p: 2
# said: 1
# s: 3
# member: 1
# reduced: 1
# used: 2
# characterize: 1
# classes: 1
# boolean: 1
# satisfiability: 1
# class: 1
# np: 1
# under: 1
# closely: 1
# have: 1
# answers: 1
# complex: 1
# than: 3
# simple: 1
# corresponding: 1
# what: 1
# divided: 1
# consists: 1
# partial: 1
# f: 5
# informal: 1
# turned: 1
# into: 3
# just: 1
# graph: 3
# associated: 3
# pairs: 1
# were: 1
# then: 2
# well: 1
# reduction: 4
# respect: 1
# however: 2
# polynomial: 2
# time: 4
# case: 2
# running: 2
# computed: 2
# pair: 1
# when: 1
# computable: 2
# alone: 1
# 2x: 1
# has: 1
# property: 1
# converted: 1
# computing: 1
# liberal: 1
# standard: 1
# sometimes: 1
# functions: 1
# complement: 1
# exactly: 1
# same: 1
# even: 1
# though: 1
# underlying: 1
# may: 1
# considered: 1
# equivalent: 1
# typical: 1
# models: 1
# computation: 1
# optimization: 4
# unlike: 1
# there: 1
# only: 1
# correct: 1
# each: 1
# concerned: 1
# finding: 1
# best: 1
# particular: 1
# arise: 1
# naturally: 1
# many: 2
# applications: 1
# traveling: 1
# salesman: 1
# linear: 1
# programming: 1
# transformed: 1
# considering: 1
# output: 1
# equal: 2
# less: 1
# value: 1
#
# Trigram Counts:
# ('in', 'computability', 'theory'): 1
# ('computability', 'theory', 'and'): 1
# ('theory', 'and', 'computational'): 1
# ('and', 'computational', 'complexity'): 1
# ('computational', 'complexity', 'theory'): 2
# ('complexity', 'theory', 'a'): 1
# ('theory', 'a', 'decision'): 1
# ('a', 'decision', 'problem'): 10
# ('decision', 'problem', 'is'): 8
# ('problem', 'is', 'a'): 2
# ('is', 'a', 'computational'): 1
# ('a', 'computational', 'problem'): 1
# ('computational', 'problem', 'that'): 1
# ('problem', 'that', 'can'): 1
# ('that', 'can', 'be'): 1
# ('can', 'be', 'posed'): 1
# ('be', 'posed', 'as'): 1
# ('posed', 'as', 'a'): 1
# ('as', 'a', 'question'): 1
# ('a', 'question', 'based'): 1
# ('question', 'based', 'on'): 1
# ('based', 'on', 'the'): 1
# ('on', 'the', 'given'): 1
# ('the', 'given', 'input'): 1
# ('given', 'input', 'values'): 1
# ('input', 'values', 'an'): 1
# ('values', 'an', 'example'): 1
# ('an', 'example', 'of'): 1
# ('example', 'of', 'a'): 2
# ('of', 'a', 'decision'): 2
# ('problem', 'is', 'deciding'): 1
# ('is', 'deciding', 'with'): 1
# ('deciding', 'with', 'the'): 1
# ('with', 'the', 'help'): 1
# ('the', 'help', 'of'): 1
# ('help', 'of', 'an'): 1
# ('of', 'an', 'algorithm'): 2
# ('an', 'algorithm', 'whether'): 1
# ('algorithm', 'whether', 'a'): 1
# ('whether', 'a', 'given'): 2
# ('a', 'given', 'natural'): 2
# ('given', 'natural', 'number'): 2
# ('natural', 'number', 'is'): 2
# ('number', 'is', 'prime'): 2
# ('is', 'prime', 'another'): 1
# ('prime', 'another', 'example'): 1
# ('another', 'example', 'is'): 1
# ('example', 'is', 'the'): 1
# ('is', 'the', 'problem'): 1
# ('the', 'problem', 'given'): 1
# ('problem', 'given', 'two'): 2
# ('given', 'two', 'numbers'): 3
# ('two', 'numbers', 'x'): 3
# ('numbers', 'x', 'and'): 3
# ('x', 'and', 'y'): 3
# ('and', 'y', 'does'): 2
# ('y', 'does', 'x'): 2
# ('does', 'x', 'evenly'): 2
# ('x', 'evenly', 'divide'): 2
# ('evenly', 'divide', 'y'): 2
# ('divide', 'y', 'a'): 1
# ('y', 'a', 'method'): 1
# ('a', 'method', 'for'): 1
# ('method', 'for', 'solving'): 1
# ('for', 'solving', 'a'): 1
# ('solving', 'a', 'decision'): 1
# ('decision', 'problem', 'given'): 2
# ('problem', 'given', 'in'): 1
# ('given', 'in', 'the'): 1
# ('in', 'the', 'form'): 1
# ('the', 'form', 'of'): 1
# ('form', 'of', 'an'): 1
# ('an', 'algorithm', 'is'): 2
# ('algorithm', 'is', 'called'): 2
# ('is', 'called', 'a'): 1
# ('called', 'a', 'decision'): 1
# ('a', 'decision', 'procedure'): 2
# ('decision', 'procedure', 'for'): 2
# ('procedure', 'for', 'that'): 1
# ('for', 'that', 'problem'): 1
# ('that', 'problem', 'a'): 1
# ('problem', 'a', 'decision'): 1
# ('procedure', 'for', 'the'): 1
# ('for', 'the', 'decision'): 1
# ('the', 'decision', 'problem'): 4
# ('divide', 'y', 'would'): 1
# ('y', 'would', 'give'): 1
# ('would', 'give', 'the'): 1
# ('give', 'the', 'steps'): 1
# ('the', 'steps', 'for'): 1
# ('steps', 'for', 'determining'): 1
# ('for', 'determining', 'whether'): 1
# ('determining', 'whether', 'x'): 1
# ('whether', 'x', 'evenly'): 1
# ('x', 'evenly', 'divides'): 1
# ('evenly', 'divides', 'one'): 1
# ('divides', 'one', 'such'): 1
# ('one', 'such', 'algorithm'): 1
# ('such', 'algorithm', 'is'): 1
# ('algorithm', 'is', 'long'): 1
# ('is', 'long', 'division'): 1
# ('long', 'division', 'if'): 1
# ('division', 'if', 'the'): 1
# ('if', 'the', 'remainder'): 1
# ('the', 'remainder', 'is'): 1
# ('remainder', 'is', 'zero'): 1
# ('is', 'zero', 'the'): 1
# ('zero', 'the', 'answer'): 1
# ('the', 'answer', 'is'): 4
# ('answer', 'is', 'otherwise'): 1
# ('is', 'otherwise', 'it'): 1
# ('or', 'strings', 'over'): 1
# ('strings', 'over', 'some'): 1
# ('over', 'some', 'other'): 1
# ('some', 'other', 'alphabet'): 1
# ('other', 'alphabet', 'the'): 1
# ('alphabet', 'the', 'subset'): 1
# ('the', 'subset', 'of'): 1
# ('subset', 'of', 'strings'): 1
# ('of', 'strings', 'for'): 1
# ('strings', 'for', 'which'): 1
# ('which', 'the', 'problem'): 1
# ('the', 'problem', 'returns'): 1
# ('problem', 'returns', 'yes'): 1
# ('returns', 'yes', 'is'): 1
# ('yes', 'is', 'a'): 3
# ('is', 'a', 'formal'): 1
# ('a', 'formal', 'language'): 1
# ('formal', 'language', 'and'): 1
# ('language', 'and', 'often'): 1
# ('and', 'often', 'decision'): 1
# ('often', 'decision', 'problems'): 1
# ('decision', 'problems', 'are'): 3
# ('problems', 'are', 'defined'): 1
# ('are', 'defined', 'as'): 1
# ('defined', 'as', 'formal'): 1
# ('as', 'formal', 'languages'): 1
# ('formal', 'languages', 'using'): 1
# ('languages', 'using', 'an'): 1
# ('using', 'an', 'encoding'): 1
# ('an', 'encoding', 'such'): 1
# ('encoding', 'such', 'as'): 1
# ('such', 'as', 'gödel'): 1
# ('as', 'gödel', 'numbering'): 1
# ('gödel', 'numbering', 'any'): 1
# ('numbering', 'any', 'string'): 1
# ('any', 'string', 'can'): 1
# ('string', 'can', 'be'): 1
# ('can', 'be', 'encoded'): 1
# ('be', 'encoded', 'as'): 1
# ('encoded', 'as', 'a'): 1
# ('as', 'a', 'natural'): 1
# ('a', 'natural', 'number'): 1
# ('natural', 'number', 'via'): 1
# ('number', 'via', 'which'): 1
# ('via', 'which', 'a'): 1
# ('which', 'a', 'decision'): 1
# ('decision', 'problem', 'can'): 2
# ('problem', 'can', 'be'): 3
# ('can', 'be', 'defined'): 1
# ('be', 'defined', 'as'): 1
# ('defined', 'as', 'a'): 1
# ('as', 'a', 'subset'): 1
# ('a', 'subset', 'of'): 2
# ('subset', 'of', 'the'): 2
# ('of', 'the', 'natural'): 2
# ('the', 'natural', 'numbers'): 2
# ('natural', 'numbers', 'therefore'): 1
# ('numbers', 'therefore', 'the'): 1
# ('therefore', 'the', 'algorithm'): 1
# ('the', 'algorithm', 'of'): 1
# ('algorithm', 'of', 'a'): 1
# ('problem', 'is', 'to'): 2
# ('is', 'to', 'compute'): 2
# ('to', 'compute', 'the'): 2
# ('compute', 'the', 'characteristic'): 1
# ('the', 'characteristic', 'function'): 2
# ('characteristic', 'function', 'of'): 2
# ('function', 'of', 'a'): 1
# ('of', 'a', 'subset'): 1
# ('natural', 'numbers', 'examples'): 1
# ('numbers', 'examples', 'a'): 1
# ('examples', 'a', 'classic'): 1
# ('a', 'classic', 'example'): 1
# ('classic', 'example', 'of'): 1
# ('of', 'a', 'decidable'): 1
# ('a', 'decidable', 'decision'): 1
# ('decidable', 'decision', 'problem'): 1
# ('problem', 'is', 'the'): 1
# ('is', 'the', 'set'): 2
# ('set', 'of', 'prime'): 1
# ('of', 'prime', 'numbers'): 1
# ('prime', 'numbers', 'it'): 1
# ('models', 'of', 'computation'): 1
# ('of', 'computation', 'optimization'): 1
# ('computation', 'optimization', 'problems'): 1
# ('optimization', 'problems', 'unlike'): 1
# ('problems', 'unlike', 'decision'): 1
# ('unlike', 'decision', 'problems'): 1
# ('problems', 'for', 'which'): 1
# ('for', 'which', 'there'): 1
# ('which', 'there', 'is'): 1
# ('there', 'is', 'only'): 1
# ('is', 'only', 'one'): 1
# ('only', 'one', 'correct'): 1
# ('one', 'correct', 'answer'): 1
# ('correct', 'answer', 'for'): 1
# ('answer', 'for', 'each'): 1
# ('for', 'each', 'input'): 1
# ('each', 'input', 'optimization'): 1
# ('input', 'optimization', 'problems'): 2
# ('optimization', 'problems', 'are'): 2
# ('problems', 'are', 'concerned'): 1
# ('are', 'concerned', 'with'): 1
# ('concerned', 'with', 'finding'): 1
# ('with', 'finding', 'the'): 1
# ('finding', 'the', 'best'): 1
# ('the', 'best', 'answer'): 1
# ('best', 'answer', 'to'): 1
# ('answer', 'to', 'a'): 1
# ('to', 'a', 'particular'): 1
# ('a', 'particular', 'input'): 1
# ('particular', 'input', 'optimization'): 1
# ('optimization', 'problems', 'arise'): 1
# ('problems', 'arise', 'naturally'): 1
# ('arise', 'naturally', 'in'): 1
# ('naturally', 'in', 'many'): 1
# ('in', 'many', 'applications'): 1
# ('many', 'applications', 'such'): 1
# ('applications', 'such', 'as'): 1
# ('such', 'as', 'the'): 1
# ('as', 'the', 'traveling'): 1
# ('the', 'traveling', 'salesman'): 1
# ('traveling', 'salesman', 'problem'): 1
# ('salesman', 'problem', 'and'): 1
# ('problem', 'and', 'many'): 1
# ('and', 'many', 'questions'): 1
# ('many', 'questions', 'in'): 1
# ('questions', 'in', 'linear'): 1
# ('in', 'linear', 'programming'): 1
# ('linear', 'programming', 'function'): 1
# ('programming', 'function', 'and'): 1
# ('function', 'and', 'optimization'): 1
# ('and', 'optimization', 'problems'): 1
# ('problems', 'are', 'often'): 1
# ('are', 'often', 'transformed'): 1
# ('often', 'transformed', 'into'): 1
# ('transformed', 'into', 'decision'): 1
# ('into', 'decision', 'problems'): 1
# ('problems', 'by', 'considering'): 1
# ('by', 'considering', 'the'): 1
# ('considering', 'the', 'question'): 1
# ('question', 'of', 'whether'): 1
# ('of', 'whether', 'the'): 1
# ('whether', 'the', 'output'): 1
# ('the', 'output', 'is'): 1
# ('output', 'is', 'equal'): 1
# ('is', 'equal', 'to'): 1
# ('equal', 'to', 'or'): 1
# ('to', 'or', 'less'): 1
# ('or', 'less', 'than'): 1
# ('less', 'than', 'or'): 1
# ('than', 'or', 'equal'): 1
# ('or', 'equal', 'to'): 1
# ('equal', 'to', 'a'): 1
# ('to', 'a', 'given'): 1
# ('a', 'given', 'value'): 1
# ('given', 'value', 'this'): 1
#
# Trigram Probabilities:
# P(theory | in, computability) = 1.0000
# P(and | computability, theory) = 1.0000
# P(computational | theory, and) = 1.0000
# P(complexity | and, computational) = 1.0000
# P(theory | computational, complexity) = 0.4000
# P(a | complexity, theory) = 0.5000
# P(decision | theory, a) = 1.0000
# P(problem | a, decision) = 0.8333
# P(is | decision, problem) = 0.4211
# P(a | problem, is) = 0.1538
# P(computational | is, a) = 0.1250
# P(problem | a, computational) = 1.0000
# P(that | computational, problem) = 1.0000
# P(can | problem, that) = 1.0000
# P(be | that, can) = 1.0000
# P(posed | can, be) = 0.1111
# P(as | be, posed) = 1.0000
# P(a | posed, as) = 1.0000
# P(question | as, a) = 0.2000
# P(based | a, question) = 0.5000
# P(on | question, based) = 1.0000
# P(the | based, on) = 1.0000
# P(given | on, the) = 0.5000
# P(input | the, given) = 1.0000
# P(values | given, input) = 1.0000
# P(an | input, values) = 1.0000
# P(example | values, an) = 1.0000
# P(of | an, example) = 1.0000
# P(a | example, of) = 1.0000
# P(decision | of, a) = 0.2857
# P(deciding | problem, is) = 0.0769
# P(with | is, deciding) = 1.0000
# P(the | deciding, with) = 1.0000
# P(help | with, the) = 0.5000
# P(of | the, help) = 1.0000
# P(an | help, of) = 1.0000
# P(algorithm | of, an) = 0.5000
# P(whether | an, algorithm) = 0.2500
# P(a | algorithm, whether) = 1.0000
# P(given | whether, a) = 1.0000
# P(natural | a, given) = 0.6667
# P(number | given, natural) = 1.0000
# P(is | natural, number) = 0.6667
# P(prime | number, is) = 1.0000
# P(another | is, prime) = 0.5000
# P(example | prime, another) = 1.0000
# P(is | another, example) = 1.0000
# P(the | example, is) = 1.0000
# P(problem | is, the) = 0.2500
# P(given | the, problem) = 0.5000
# P(two | problem, given) = 0.6667
# P(numbers | given, two) = 1.0000
# P(x | two, numbers) = 1.0000
# P(and | numbers, x) = 1.0000
# P(y | x, and) = 1.0000
# P(does | and, y) = 0.6667
# P(x | y, does) = 1.0000
# P(evenly | does, x) = 1.0000
# P(divide | x, evenly) = 0.6667
# P(y | evenly, divide) = 1.0000
# P(a | divide, y) = 0.5000
# P(method | y, a) = 0.5000
# P(for | a, method) = 1.0000
# P(solving | method, for) = 1.0000
# P(a | for, solving) = 1.0000
# P(decision | solving, a) = 1.0000
# P(given | decision, problem) = 0.1053
# P(in | problem, given) = 0.3333
# P(the | given, in) = 1.0000
# P(form | in, the) = 1.0000
# P(of | the, form) = 1.0000
# P(an | form, of) = 1.0000
# P(is | an, algorithm) = 0.5000
# P(called | algorithm, is) = 0.6667
# P(a | is, called) = 0.5000
# P(decision | called, a) = 1.0000
# P(procedure | a, decision) = 0.1667
# P(for | decision, procedure) = 1.0000
# P(that | procedure, for) = 0.5000
# P(problem | for, that) = 1.0000
# P(a | that, problem) = 1.0000
# P(decision | problem, a) = 1.0000
# P(the | procedure, for) = 0.5000
# P(decision | for, the) = 0.3333
# P(problem | the, decision) = 1.0000
# P(would | divide, y) = 0.5000
# P(give | y, would) = 1.0000
# P(the | would, give) = 1.0000
# P(steps | give, the) = 1.0000
# P(for | the, steps) = 1.0000
# P(determining | steps, for) = 1.0000
# P(whether | for, determining) = 1.0000
# P(x | determining, whether) = 1.0000
# P(evenly | whether, x) = 1.0000
# P(divides | x, evenly) = 0.3333
# P(one | evenly, divides) = 1.0000
# P(such | divides, one) = 1.0000
# P(algorithm | one, such) = 1.0000
# P(is | such, algorithm) = 1.0000
# P(long | algorithm, is) = 0.3333
# P(division | is, long) = 1.0000
# P(if | long, division) = 1.0000
# P(the | division, if) = 1.0000
# P(remainder | if, the) = 0.3333
# P(is | the, remainder) = 1.0000
# P(zero | remainder, is) = 1.0000
# P(the | is, zero) = 1.0000
# P(answer | zero, the) = 1.0000
# P(is | the, answer) = 1.0000
# P(otherwise | answer, is) = 0.2500
# P(it | is, otherwise) = 1.0000
# P(is | otherwise, it) = 1.0000
# P(a | it, is) = 0.1667
# P(decision | is, a) = 0.1250
# P(which | decision, problem) = 0.0526
# P(can | problem, which) = 1.0000
# P(be | which, can) = 0.5000
# P(solved | can, be) = 0.1111
# P(by | be, solved) = 1.0000
# P(an | solved, by) = 1.0000
# P(algorithm | by, an) = 1.0000
# P(decidable | is, called) = 0.5000
# P(decision | called, decidable) = 1.0000
# P(problems | decidable, decision) = 0.6667
# P(typically | decision, problems) = 0.0769
# P(appear | problems, typically) = 1.0000
# P(in | typically, appear) = 1.0000
# P(mathematical | appear, in) = 1.0000
# P(questions | in, mathematical) = 1.0000
# P(of | mathematical, questions) = 1.0000
# P(decidability | questions, of) = 1.0000
# P(that | of, decidability) = 1.0000
# P(is | decidability, that) = 1.0000
# P(the | that, is) = 1.0000
# P(question | is, the) = 0.2500
# P(of | the, question) = 1.0000
# P(the | question, of) = 0.5000
# P(existence | of, the) = 0.1000
# P(of | the, existence) = 1.0000
# P(an | existence, of) = 0.3333
# P(effective | of, an) = 0.2500
# P(method | an, effective) = 1.0000
# P(to | effective, method) = 0.5000
# P(determine | method, to) = 1.0000
# P(the | to, determine) = 1.0000
# P(existence | determine, the) = 1.0000
# P(some | existence, of) = 0.3333
# P(object | of, some) = 0.5000
# P(or | some, object) = 1.0000
# P(its | object, or) = 1.0000
# P(membership | or, its) = 1.0000
# P(in | its, membership) = 1.0000
# P(a | membership, in) = 1.0000
# P(set | in, a) = 1.0000
# P(some | a, set) = 0.5000
# P(of | set, some) = 1.0000
# P(the | some, of) = 1.0000
# P(most | of, the) = 0.1000
# P(important | the, most) = 0.5000
# P(problems | most, important) = 1.0000
# P(in | important, problems) = 1.0000
# P(mathematics | problems, in) = 1.0000
# P(are | in, mathematics) = 1.0000
# P(undecidable | mathematics, are) = 1.0000
# P(the | are, undecidable) = 0.5000
# P(field | undecidable, the) = 1.0000
# P(of | the, field) = 1.0000
# P(computational | field, of) = 0.5000
# P(complexity | of, computational) = 1.0000
# P(categorizes | computational, complexity) = 0.2000
# P(decidable | complexity, categorizes) = 1.0000
# P(decision | categorizes, decidable) = 1.0000
# P(by | decision, problems) = 0.2308
# P(how | problems, by) = 0.3333
# P(difficult | by, how) = 1.0000
# P(they | how, difficult) = 1.0000
# P(are | difficult, they) = 1.0000
# P(to | they, are) = 1.0000
# P(solve | are, to) = 1.0000
# P(difficult | to, solve) = 1.0000
# P(in | solve, difficult) = 1.0000
# P(this | difficult, in) = 1.0000
# P(sense | in, this) = 1.0000
# P(is | this, sense) = 1.0000
# P(described | sense, is) = 1.0000
# P(in | is, described) = 1.0000
# P(terms | described, in) = 1.0000
# P(of | in, terms) = 1.0000
# P(the | terms, of) = 1.0000
# P(computational | of, the) = 0.1000
# P(resources | the, computational) = 1.0000
# P(needed | computational, resources) = 1.0000
# P(by | resources, needed) = 1.0000
# P(the | needed, by) = 1.0000
# P(most | by, the) = 1.0000
# P(efficient | the, most) = 0.5000
# P(algorithm | most, efficient) = 1.0000
# P(for | efficient, algorithm) = 1.0000
# P(a | algorithm, for) = 1.0000
# P(certain | for, a) = 0.5000
# P(problem | a, certain) = 1.0000
# P(the | certain, problem) = 1.0000
# P(field | problem, the) = 0.5000
# P(recursion | field, of) = 0.5000
# P(theory | of, recursion) = 1.0000
# P(meanwhile | recursion, theory) = 1.0000
# P(categorizes | theory, meanwhile) = 1.0000
# P(undecidable | meanwhile, categorizes) = 1.0000
# P(decision | categorizes, undecidable) = 1.0000
# P(problems | undecidable, decision) = 0.5000
# P(turing | problems, by) = 0.3333
# P(degree | by, turing) = 1.0000
# P(which | turing, degree) = 1.0000
# P(is | degree, which) = 1.0000
# P(a | which, is) = 1.0000
# P(measure | is, a) = 0.1250
# P(of | a, measure) = 1.0000
# P(the | measure, of) = 1.0000
# P(noncomputability | of, the) = 0.1000
# P(inherent | the, noncomputability) = 1.0000
# P(in | noncomputability, inherent) = 1.0000
# P(any | inherent, in) = 1.0000
# P(solution | in, any) = 1.0000
# P(definition | any, solution) = 1.0000
# P(a | solution, definition) = 1.0000
# P(decision | definition, a) = 1.0000
# P(question | is, a) = 0.1250
# P(on | a, question) = 0.5000
# P(an | question, on) = 1.0000
# P(infinite | on, an) = 1.0000
# P(set | an, infinite) = 1.0000
# P(of | infinite, set) = 1.0000
# P(inputs | set, of) = 0.5000
# P(it | of, inputs) = 0.2500
# P(is | inputs, it) = 1.0000
# P(traditional | it, is) = 0.1667
# P(to | is, traditional) = 1.0000
# P(define | traditional, to) = 1.0000
# P(the | to, define) = 1.0000
# P(decision | define, the) = 1.0000
# P(as | decision, problem) = 0.0526
# P(the | problem, as) = 1.0000
# P(set | as, the) = 0.5000
# P(of | the, set) = 0.8571
# P(possible | set, of) = 0.1250
# P(inputs | of, possible) = 1.0000
# P(together | possible, inputs) = 1.0000
# P(with | inputs, together) = 1.0000
# P(the | together, with) = 1.0000
# P(set | with, the) = 0.5000
# P(for | of, inputs) = 0.2500
# P(which | inputs, for) = 1.0000
# P(the | for, which) = 0.6667
# P(answer | which, the) = 0.7500
# P(yes | answer, is) = 0.7500
# P(these | is, yes) = 0.3333
# P(inputs | yes, these) = 1.0000
# P(can | these, inputs) = 1.0000
# P(be | inputs, can) = 1.0000
# P(natural | can, be) = 0.1111
# P(numbers | be, natural) = 1.0000
# P(but | natural, numbers) = 0.2000
# P(can | numbers, but) = 1.0000
# P(also | but, can) = 1.0000
# P(be | can, also) = 1.0000
# P(values | also, be) = 1.0000
# P(of | be, values) = 1.0000
# P(some | values, of) = 0.5000
# P(other | of, some) = 0.5000
# P(kind | some, other) = 0.5000
# P(like | other, kind) = 1.0000
# P(binary | kind, like) = 1.0000
# P(strings | like, binary) = 1.0000
# P(or | binary, strings) = 1.0000
# P(strings | strings, or) = 1.0000
# P(over | or, strings) = 1.0000
# P(some | strings, over) = 1.0000
# P(other | over, some) = 1.0000
# P(alphabet | some, other) = 0.5000
# P(the | other, alphabet) = 1.0000
# P(subset | alphabet, the) = 1.0000
# P(of | the, subset) = 1.0000
# P(strings | subset, of) = 0.3333
# P(for | of, strings) = 1.0000
# P(which | strings, for) = 1.0000
# P(problem | which, the) = 0.2500
# P(returns | the, problem) = 0.5000
# P(yes | problem, returns) = 1.0000
# P(is | returns, yes) = 1.0000
# P(a | yes, is) = 1.0000
# P(formal | is, a) = 0.1250
# P(language | a, formal) = 1.0000
# P(and | formal, language) = 1.0000
# P(often | language, and) = 1.0000
# P(decision | and, often) = 1.0000
# P(problems | often, decision) = 1.0000
# P(are | decision, problems) = 0.2308
# P(defined | problems, are) = 0.2000
# P(as | are, defined) = 1.0000
# P(formal | defined, as) = 0.5000
# P(languages | as, formal) = 1.0000
# P(using | formal, languages) = 1.0000
# P(an | languages, using) = 1.0000
# P(encoding | using, an) = 1.0000
# P(such | an, encoding) = 1.0000
# P(as | encoding, such) = 1.0000
# P(gödel | such, as) = 0.3333
# P(numbering | as, gödel) = 1.0000
# P(any | gödel, numbering) = 1.0000
# P(string | numbering, any) = 1.0000
# P(can | any, string) = 1.0000
# P(be | string, can) = 1.0000
# P(encoded | can, be) = 0.1111
# P(as | be, encoded) = 1.0000
# P(a | encoded, as) = 1.0000
# P(natural | as, a) = 0.2000
# P(number | a, natural) = 1.0000
# P(via | natural, number) = 0.3333
# P(which | number, via) = 1.0000
# P(a | via, which) = 1.0000
# P(decision | which, a) = 1.0000
# P(can | decision, problem) = 0.1053
# P(be | problem, can) = 1.0000
# ...
# P(the | solvable, if) = 1.0000
# P(set | if, the) = 0.6667
# P(or | of, inputs) = 0.5000
# P(natural | inputs, or) = 1.0000
# P(numbers | or, natural) = 1.0000
# P(for | natural, numbers) = 0.4000
# P(which | numbers, for) = 1.0000
# P(is | is, yes) = 0.6667
# P(recursive | is, a) = 0.1250
# P(set | a, recursive) = 1.0000
# P(a | recursive, set) = 1.0000
# P(problem | set, a) = 1.0000
# P(is | a, problem) = 1.0000
# P(partially | problem, is) = 0.0769
# P(decidable | is, partially) = 1.0000
# P(semidecidable | partially, decidable) = 1.0000
# P(solvable | decidable, semidecidable) = 1.0000
# P(or | semidecidable, solvable) = 1.0000
# P(provable | solvable, or) = 1.0000
# P(if | or, provable) = 1.0000
# P(the | provable, if) = 1.0000
# P(recursively | is, a) = 0.1250
# P(enumerable | a, recursively) = 1.0000
# P(set | recursively, enumerable) = 1.0000
# P(problems | enumerable, set) = 1.0000
# P(that | set, problems) = 1.0000
# P(are | problems, that) = 1.0000
# P(not | that, are) = 0.5000
# P(decidable | are, not) = 1.0000
# P(are | not, decidable) = 1.0000
# P(undecidable | decidable, are) = 1.0000
# P(for | are, undecidable) = 0.5000
# P(those | undecidable, for) = 1.0000
# P(it | for, those) = 1.0000
# P(is | those, it) = 1.0000
# P(not | it, is) = 0.1667
# P(possible | is, not) = 0.5000
# P(to | not, possible) = 1.0000
# P(create | possible, to) = 0.5000
# P(an | to, create) = 1.0000
# P(algorithm | create, an) = 1.0000
# P(efficient | an, algorithm) = 0.2500
# P(or | algorithm, efficient) = 1.0000
# P(otherwise | efficient, or) = 1.0000
# P(that | or, otherwise) = 1.0000
# P(solves | otherwise, that) = 1.0000
# P(them | that, solves) = 1.0000
# P(the | solves, them) = 1.0000
# P(halting | them, the) = 1.0000
# P(problem | the, halting) = 1.0000
# P(is | halting, problem) = 1.0000
# P(an | problem, is) = 0.0769
# P(important | is, an) = 1.0000
# P(undecidable | an, important) = 1.0000
# P(decision | important, undecidable) = 1.0000
# P(problem | undecidable, decision) = 0.5000
# P(for | decision, problem) = 0.0526
# P(more | problem, for) = 1.0000
# P(examples | for, more) = 1.0000
# P(see | more, examples) = 1.0000
# P(list | examples, see) = 1.0000
# P(of | see, list) = 1.0000
# P(undecidable | list, of) = 1.0000
# P(problems | of, undecidable) = 1.0000
# P(complete | undecidable, problems) = 1.0000
# P(problems | problems, complete) = 1.0000
# P(decision | complete, problems) = 1.0000
# P(problems | problems, decision) = 1.0000
# P(can | decision, problems) = 0.0769
# P(be | problems, can) = 1.0000
# P(ordered | can, be) = 0.1111
# P(according | be, ordered) = 1.0000
# P(to | ordered, according) = 1.0000
# P(reducibility | according, to) = 1.0000
# P(and | to, reducibility) = 1.0000
# P(related | reducibility, and) = 1.0000
# P(to | and, related) = 1.0000
# P(feasible | related, to) = 0.5000
# P(reductions | to, feasible) = 1.0000
# P(such | feasible, reductions) = 1.0000
# P(as | reductions, such) = 1.0000
# P(reductions | such, as) = 0.3333
# P(a | as, reductions) = 1.0000
# P(decision | reductions, a) = 1.0000
# P(p | decision, problem) = 0.0526
# P(is | problem, p) = 1.0000
# P(said | p, is) = 0.5000
# P(to | is, said) = 1.0000
# P(be | said, to) = 1.0000
# P(complete | to, be) = 0.5000
# P(for | be, complete) = 1.0000
# P(a | complete, for) = 0.5000
# P(set | for, a) = 0.5000
# P(of | a, set) = 0.5000
# P(decision | set, of) = 0.1250
# P(problems | of, decision) = 1.0000
# P(s | decision, problems) = 0.0769
# P(if | problems, s) = 1.0000
# P(p | s, if) = 1.0000
# P(is | if, p) = 1.0000
# P(a | p, is) = 0.5000
# P(member | is, a) = 0.1250
# P(of | a, member) = 1.0000
# P(s | member, of) = 1.0000
# P(and | of, s) = 1.0000
# P(every | s, and) = 1.0000
# P(problem | and, every) = 1.0000
# P(in | every, problem) = 1.0000
# P(s | problem, in) = 1.0000
# P(can | in, s) = 1.0000
# P(be | s, can) = 1.0000
# P(reduced | can, be) = 0.1111
# P(to | be, reduced) = 1.0000
# P(complete | reduced, to) = 1.0000
# P(decision | to, complete) = 1.0000
# P(problems | complete, decision) = 1.0000
# P(used | problems, are) = 0.2000
# P(in | are, used) = 1.0000
# P(computational | used, in) = 1.0000
# P(complexity | in, computational) = 1.0000
# P(to | complexity, theory) = 0.5000
# P(characterize | theory, to) = 1.0000
# P(complexity | to, characterize) = 1.0000
# P(classes | characterize, complexity) = 1.0000
# P(of | complexity, classes) = 1.0000
# P(decision | classes, of) = 1.0000
# P(for | decision, problems) = 0.1538
# P(example | problems, for) = 0.5000
# P(the | for, example) = 0.6667
# P(boolean | example, the) = 0.5000
# P(satisfiability | the, boolean) = 1.0000
# P(problem | boolean, satisfiability) = 1.0000
# P(is | satisfiability, problem) = 1.0000
# P(complete | problem, is) = 0.0769
# P(for | is, complete) = 1.0000
# P(the | complete, for) = 0.5000
# P(class | for, the) = 0.3333
# P(np | the, class) = 1.0000
# P(of | class, np) = 1.0000
# P(decision | np, of) = 1.0000
# P(under | decision, problems) = 0.0769
# P(reducibility | problems, under) = 1.0000
# P(function | under, reducibility) = 1.0000
# P(problems | reducibility, function) = 1.0000
# P(decision | function, problems) = 0.5000
# P(closely | problems, are) = 0.2000
# P(related | are, closely) = 1.0000
# P(to | closely, related) = 1.0000
# P(function | related, to) = 0.5000
# P(problems | to, function) = 1.0000
# P(which | function, problems) = 0.5000
# P(can | problems, which) = 1.0000
# P(have | which, can) = 0.5000
# P(answers | can, have) = 1.0000
# P(that | have, answers) = 1.0000
# P(are | answers, that) = 1.0000
# P(more | that, are) = 0.5000
# P(complex | are, more) = 1.0000
# P(than | more, complex) = 1.0000
# P(a | complex, than) = 1.0000
# P(simple | than, a) = 1.0000
# P(or | a, simple) = 1.0000
# P(a | simple, or) = 1.0000
# P(corresponding | or, a) = 1.0000
# P(function | a, corresponding) = 1.0000
# P(problem | corresponding, function) = 1.0000
# P(is | function, problem) = 0.2000
# P(given | problem, is) = 0.0769
# P(two | is, given) = 1.0000
# P(what | and, y) = 0.3333
# P(is | y, what) = 1.0000
# P(x | what, is) = 1.0000
# P(divided | is, x) = 1.0000
# P(by | x, divided) = 1.0000
# P(y | divided, by) = 1.0000
# P(a | by, y) = 1.0000
# P(function | y, a) = 0.5000
# P(problem | a, function) = 0.2000
# P(consists | function, problem) = 0.2000
# P(of | problem, consists) = 1.0000
# P(a | consists, of) = 1.0000
# P(partial | of, a) = 0.1429
# P(function | a, partial) = 1.0000
# P(f | partial, function) = 1.0000
# P(the | function, f) = 0.3333
# P(informal | f, the) = 1.0000
# P(problem | the, informal) = 1.0000
# P(is | informal, problem) = 1.0000
# P(values | compute, the) = 0.5000
# P(of | the, values) = 1.0000
# P(f | values, of) = 0.5000
# P(on | of, f) = 1.0000
# P(the | f, on) = 1.0000
# P(inputs | on, the) = 0.5000
# P(for | the, inputs) = 1.0000
# P(it | for, which) = 0.1667
# P(is | which, it) = 1.0000
# P(defined | it, is) = 0.1667
# P(every | is, defined) = 1.0000
# P(function | defined, every) = 1.0000
# P(problem | every, function) = 1.0000
# P(can | function, problem) = 0.2000
# P(turned | can, be) = 0.1111
# P(into | be, turned) = 1.0000
# P(a | turned, into) = 1.0000
# P(decision | into, a) = 1.0000
# P(the | decision, problem) = 0.0526
# P(decision | problem, the) = 0.5000
# P(just | problem, is) = 0.0769
# P(the | is, just) = 1.0000
# P(graph | just, the) = 1.0000
# P(of | the, graph) = 1.0000
# P(the | graph, of) = 0.3333
# P(associated | of, the) = 0.1000
# P(function | the, associated) = 0.5000
# P(the | associated, function) = 1.0000
# P(graph | function, the) = 1.0000
# P(a | graph, of) = 0.6667
# P(function | of, a) = 0.2857
# P(f | a, function) = 0.2000
# P(is | function, f) = 0.3333
# P(the | f, is) = 1.0000
# P(pairs | set, of) = 0.1250
# P(x | of, pairs) = 1.0000
# P(y | pairs, x) = 1.0000
# P(such | x, y) = 0.3333
# P(that | y, such) = 1.0000
# P(f | such, that) = 1.0000
# P(x | that, f) = 1.0000
# P(y | f, x) = 0.5000
# P(if | x, y) = 0.3333
# P(this | y, if) = 1.0000
# P(decision | if, this) = 0.5000
# P(problem | this, decision) = 1.0000
# P(were | decision, problem) = 0.0526
# P(effectively | problem, were) = 1.0000
# P(solvable | were, effectively) = 1.0000
# P(then | effectively, solvable) = 0.5000
# P(the | solvable, then) = 1.0000
# P(function | then, the) = 0.5000
# P(problem | the, function) = 0.5000
# P(would | function, problem) = 0.2000
# P(be | problem, would) = 1.0000
# P(as | would, be) = 1.0000
# P(well | be, as) = 1.0000
# P(this | as, well) = 1.0000
# P(reduction | well, this) = 1.0000
# P(does | this, reduction) = 0.5000
# P(not | reduction, does) = 1.0000
# P(respect | does, not) = 1.0000
# P(computational | not, respect) = 1.0000
# P(complexity | respect, computational) = 1.0000
# P(however | computational, complexity) = 0.2000
# P(for | complexity, however) = 1.0000
# P(example | however, for) = 1.0000
# P(it | for, example) = 0.3333
# P(is | example, it) = 1.0000
# P(for | is, possible) = 0.5000
# P(the | possible, for) = 1.0000
# P(graph | for, the) = 0.3333
# P(to | a, function) = 0.2000
# P(be | function, to) = 1.0000
# P(decidable | to, be) = 0.5000
# P(in | be, decidable) = 1.0000
# P(polynomial | decidable, in) = 1.0000
# P(time | in, polynomial) = 1.0000
# P(in | polynomial, time) = 1.0000
# P(which | time, in) = 1.0000
# P(case | in, which) = 1.0000
# P(running | which, case) = 1.0000
# P(time | case, running) = 1.0000
# P(is | running, time) = 1.0000
# P(computed | time, is) = 1.0000
# P(as | is, computed) = 1.0000
# P(a | computed, as) = 1.0000
# P(function | as, a) = 0.4000
# P(of | a, function) = 0.4000
# P(the | function, of) = 0.5000
# P(pair | of, the) = 0.1000
# P(x | the, pair) = 1.0000
# P(y | pair, x) = 1.0000
# P(when | x, y) = 0.3333
# P(the | y, when) = 1.0000
# P(function | when, the) = 1.0000
# P(is | the, function) = 0.2500
# P(not | function, is) = 0.5000
# P(computable | is, not) = 0.5000
# P(in | not, computable) = 1.0000
# P(polynomial | computable, in) = 1.0000
# P(x | function, of) = 0.2500
# P(alone | of, x) = 1.0000
# P(the | x, alone) = 1.0000
# P(function | alone, the) = 1.0000
# P(f | the, function) = 0.2500
# P(x | function, f) = 0.3333
# P(2x | f, x) = 0.5000
# P(has | x, 2x) = 1.0000
# P(this | 2x, has) = 1.0000
# P(property | has, this) = 1.0000
# P(every | this, property) = 1.0000
# P(decision | property, every) = 1.0000
# P(problem | every, decision) = 1.0000
# P(converted | can, be) = 0.1111
# P(into | be, converted) = 1.0000
# P(the | converted, into) = 1.0000
# P(function | into, the) = 1.0000
# P(of | function, problem) = 0.2000
# P(computing | problem, of) = 1.0000
# P(the | of, computing) = 1.0000
# P(characteristic | computing, the) = 1.0000
# P(set | of, the) = 0.1000
# P(associated | the, set) = 0.1429
# P(to | set, associated) = 1.0000
# P(the | associated, to) = 1.0000
# P(decision | to, the) = 1.0000
# P(if | decision, problem) = 0.0526
# P(this | problem, if) = 1.0000
# P(function | if, this) = 0.5000
# P(is | this, function) = 1.0000
# P(computable | function, is) = 0.5000
# P(then | is, computable) = 1.0000
# P(the | computable, then) = 1.0000
# P(associated | then, the) = 0.5000
# P(decision | the, associated) = 0.5000
# P(problem | associated, decision) = 1.0000
# P(however | is, decidable) = 0.5000
# P(this | decidable, however) = 1.0000
# P(reduction | however, this) = 1.0000
# P(is | this, reduction) = 0.5000
# P(more | reduction, is) = 1.0000
# P(liberal | is, more) = 1.0000
# P(than | more, liberal) = 1.0000
# P(the | liberal, than) = 1.0000
# P(standard | than, the) = 1.0000
# P(reduction | the, standard) = 1.0000
# P(used | standard, reduction) = 1.0000
# P(in | reduction, used) = 1.0000
# P(sometimes | computational, complexity) = 0.2000
# P(called | complexity, sometimes) = 1.0000
# P(reduction | sometimes, called) = 1.0000
# P(for | called, reduction) = 1.0000
# P(example | reduction, for) = 1.0000
# P(complexity | example, the) = 0.5000
# P(of | the, complexity) = 1.0000
# P(the | complexity, of) = 1.0000
# P(characteristic | of, the) = 0.1000
# P(functions | the, characteristic) = 0.3333
# P(of | characteristic, functions) = 1.0000
# P(an | functions, of) = 1.0000
# P(problem | of, an) = 0.2500
# P(and | an, problem) = 1.0000
# P(its | problem, and) = 0.5000
# P(complement | and, its) = 1.0000
# P(is | its, complement) = 1.0000
# P(exactly | complement, is) = 1.0000
# P(the | is, exactly) = 1.0000
# P(same | exactly, the) = 1.0000
# P(even | the, same) = 1.0000
# P(though | same, even) = 1.0000
# P(the | even, though) = 1.0000
# P(underlying | though, the) = 1.0000
# P(decision | the, underlying) = 1.0000
# P(problems | underlying, decision) = 1.0000
# P(may | decision, problems) = 0.0769
# P(not | problems, may) = 1.0000
# P(be | may, not) = 1.0000
# P(considered | not, be) = 1.0000
# P(equivalent | be, considered) = 1.0000
# P(in | considered, equivalent) = 1.0000
# P(some | equivalent, in) = 1.0000
# P(typical | in, some) = 1.0000
# P(models | some, typical) = 1.0000
# P(of | typical, models) = 1.0000
# P(computation | models, of) = 1.0000
# P(optimization | of, computation) = 1.0000
# P(problems | computation, optimization) = 1.0000
# P(unlike | optimization, problems) = 0.2500
# P(decision | problems, unlike) = 1.0000
# P(problems | unlike, decision) = 1.0000
# P(which | problems, for) = 0.5000
# P(there | for, which) = 0.1667
# P(is | which, there) = 1.0000
# P(only | there, is) = 1.0000
# P(one | is, only) = 1.0000
# P(correct | only, one) = 1.0000
# P(answer | one, correct) = 1.0000
# P(for | correct, answer) = 1.0000
# P(each | answer, for) = 1.0000
# P(input | for, each) = 1.0000
# P(optimization | each, input) = 1.0000
# P(problems | input, optimization) = 1.0000
# P(are | optimization, problems) = 0.5000
# P(concerned | problems, are) = 0.2000
# P(with | are, concerned) = 1.0000
# P(finding | concerned, with) = 1.0000
# P(the | with, finding) = 1.0000
# P(best | finding, the) = 1.0000
# P(answer | the, best) = 1.0000
# P(to | best, answer) = 1.0000
# P(a | answer, to) = 1.0000
# P(particular | to, a) = 0.5000
# P(input | a, particular) = 1.0000
# P(optimization | particular, input) = 1.0000
# P(arise | optimization, problems) = 0.2500
# P(naturally | problems, arise) = 1.0000
# P(in | arise, naturally) = 1.0000
# P(many | naturally, in) = 1.0000
# P(applications | in, many) = 1.0000
# P(such | many, applications) = 1.0000
# P(as | applications, such) = 1.0000
# P(the | such, as) = 0.3333
# P(traveling | as, the) = 0.5000
# P(salesman | the, traveling) = 1.0000
# P(problem | traveling, salesman) = 1.0000
# P(and | salesman, problem) = 1.0000
# P(many | problem, and) = 0.5000
# P(questions | and, many) = 1.0000
# P(in | many, questions) = 1.0000
# P(linear | questions, in) = 1.0000
# P(programming | in, linear) = 1.0000
# P(function | linear, programming) = 1.0000
# P(and | programming, function) = 1.0000
# P(optimization | function, and) = 1.0000
# P(problems | and, optimization) = 1.0000
# P(often | problems, are) = 0.2000
# P(transformed | are, often) = 1.0000
# P(into | often, transformed) = 1.0000
# P(decision | transformed, into) = 1.0000
# P(problems | into, decision) = 1.0000
# P(considering | problems, by) = 0.3333
# P(the | by, considering) = 1.0000
# P(question | considering, the) = 1.0000
# P(whether | question, of) = 0.5000
# P(the | of, whether) = 1.0000
# P(output | whether, the) = 1.0000
# P(is | the, output) = 1.0000
# P(equal | output, is) = 1.0000
# P(to | is, equal) = 1.0000
# P(or | equal, to) = 0.5000
# P(less | to, or) = 1.0000
# P(than | or, less) = 1.0000
# P(or | less, than) = 1.0000
# P(equal | than, or) = 1.0000
# P(to | or, equal) = 1.0000
# P(a | equal, to) = 0.5000
# P(given | to, a) = 0.5000
# P(value | a, given) = 0.3333
# P(this | given, value) = 1.0000
#
# Predicted next word after 'decision problem': is
#
# Generated Text: decision problem is a computational problem that can be posed as a
#
# Evaluation on Test Sentence:
# Test Sentence: decision problem is a concept related to algorithms
# Given 'decision problem', Actual: 'is', Predicted: 'is'
# Given 'problem is', Actual: 'a', Predicted: 'a'
# Given 'is a', Actual: 'concept', Predicted: 'computational'
# Given 'a concept', Actual: 'related', Predicted: 'None'
# Given 'concept related', Actual: 'to', Predicted: 'None'
# Given 'related to', Actual: 'algorithms', Predicted: 'feasible'
#
# Prediction Accuracy: 33.33%
#
# Trigram Model Perplexity (Sentence: The quick brown fox jumps over the lazy dog near the bank of the river.):  464158883.3613
#
# Trigram Model Perplexity (Sentence: In computability theory and computational complexity theory, a decision problem is a computational problem that can be posed as a yes-no question based on the given input values.):  1.5482
#
# Trigram Model Perplexity (Sentence: A decision problem which can be solved by an algorithm is called decidable.):  1.8234
